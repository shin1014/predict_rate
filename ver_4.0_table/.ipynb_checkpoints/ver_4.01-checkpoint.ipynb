# %%
# -*- coding: utf-8 -*-
from oandapyV20 import API
from oandapyV20.exceptions import V20Error
from oandapyV20.endpoints.pricing import PricingStream
import oandapyV20.endpoints.orders as orders
import oandapyV20.endpoints.instruments as instruments

import shutil
import os
import csv
import sys

import json
import datetime
import pandas as pd
import numpy as np
import talib as ta
import math

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


#自分のアカウント、トークンをセット
accountID = "101-009-16415310-001"
access_token = '860c2d2dbbcd01b6d95939b6af6b5981-8664724ce0870220c55161d704137df6'

api = API(access_token=access_token, environment="practice")
        
# Oandaからcandleデータを取得する。
def getCandleDataFromOanda(instrument, api, date_from, date_to, granularity):
    params = {
        "from": date_from.isoformat(),
        "to": date_to.isoformat(),
        "granularity": granularity,
    }
    r = instruments.InstrumentsCandles(instrument=instrument, params=params)
    return api.request(r)

def oandaJsonToPythonList(JSONRes):
    
    data = []
    for res in JSONRes['candles']:
        temp = [((datetime.datetime.fromisoformat(res['time'][:19]))+datetime.timedelta(hours=+9)).strftime('%Y-%m-%d %H:%M')]#indexとなる時間を追加
        temp.extend([res['volume'],
            res['mid']['o'],
            res['mid']['h'],
            res['mid']['l'],
            res['mid']['c'],
            ])
        data.append(temp)
    return data

def logarism(x):
    x = abs(x)
    return math.log(x)


def get_now_data(time, period_hours, money, foot, back_hours = 0, times = 0):
    global BACK
    all_data = []
    #time = time.replace(hour=7, hour=0, second=0, microsecond=0)
    #入力された日の当日の7時
    
    NY = datetime.timedelta(hours=-14)
    back = datetime.timedelta(hours=-back_hours)
    
    force = datetime.timedelta(hours=-BACK)
    
    date_to = time + NY + datetime.timedelta(seconds=-1) + back + force

    date_from = date_to + datetime.timedelta(hours=-period_hours)
    for i in range(times+1):    
        ret = getCandleDataFromOanda(money, api, date_from, date_to, foot)
        month_data = oandaJsonToPythonList(ret)#取得したデータを格納

        all_data.extend(month_data)#データを追加
        
        date_to = date_from
        date_from = date_to + datetime.timedelta(hours=-period_hours)
#         print(date_from, date_to)

    # pandas DataFrameへ変換
    df = pd.DataFrame(all_data)

#     print(date_from, date_to)
#     print(df)
    
    df.columns = ['Datetime','Volume', 'Open', 'High', 'Low', 'Close']
    
    df['Volume'] = df['Volume'].astype('double')
    df['Open'] = df['Open'].astype('double')
    df['Close'] = df['Close'].astype('double')
    df['High'] = df['High'].astype('double')
    df['Low'] = df['Low'].astype('double')
    
    
    close = np.array(df["Close"]).astype(float)
#     #以下、talibを用いてテクニカル指標（今回の学習で用いる特徴量）を算出しdf_feature入れる
#     #単純移動平均は、単純移動平均値とその日の終値の比を特徴量として用いる
    df["SMA2"]= ta.SMA(close, timeperiod=2) / close
#     df["SMA3"]= ta.SMA(close, timeperiod=3) / close
#     df["SMA4"]= ta.SMA(close, timeperiod=4) / close
    df["SMA5"]= ta.SMA(close, timeperiod=5) / close
#     df["SMA6"]= ta.SMA(close, timeperiod=6) / close
#     df["SMA7"]= ta.SMA(close, timeperiod=7) / close
#     df["SMA8"]= ta.SMA(close, timeperiod=8) / close
#     df["SMA9"]= ta.SMA(close, timeperiod=9) / close
    df["SMA10"]= ta.SMA(close, timeperiod=10) / close
    df["RSI"] = ta.RSI(close, timeperiod=9) / close
    #ボリンジャーバンド Main 
    upper, middle, lower = ta.BBANDS(close, timeperiod=10, nbdevup=2, nbdevdn=2)
    df["BBANDS+σ"] = upper / close * 1000
    df["BBANDS-σ"] = lower / close * 1000
    
    #df['Rate']=(df['Close']-df['Open'])/df['Open']
    
#     df['Open'] = df['Open'].apply(lambda x: logarism(x))
#     df['Close'] = df['Close'].apply(lambda x: logarism(x))
    
    df["SMA2"]= df["SMA2"].apply(lambda x: logarism(x)) * 1000
#     df["SMA3"]= df["SMA3"].apply(lambda x: logarism(x)) * 1000
#     df["SMA4"]= df["SMA4"].apply(lambda x: logarism(x)) * 1000
    df["SMA5"]= df["SMA5"].apply(lambda x: logarism(x)) * 1000
#     df["SMA6"]= df["SMA6"].apply(lambda x: logarism(x)) * 1000
#     df["SMA7"]= df["SMA7"].apply(lambda x: logarism(x)) * 1000
#     df["SMA8"]= df["SMA8"].apply(lambda x: logarism(x)) * 1000
#     df["SMA9"]= df["SMA9"].apply(lambda x: logarism(x)) * 1000
    df["SMA10"]= df["SMA10"].apply(lambda x: logarism(x)) * 1000
    
#     df["MACD"], _ , _= ta.MACD(close, fastperiod=3, slowperiod=18, signalperiod=9)/close
    
    
#     df['Rate']=(df['Close'].astype('double')-df['Open'].astype('double'))/df['Open'].astype('double')
    
#     df['Rate'] = df['Rate']*1000
#     df['true']=(df['Close'].astype('double')-df['Open'].astype('double'))/df['Open'].astype('double')
    
    df['class'] = ((df['Close'].astype('double')-df['Open'].astype('double'))/df['Open'].astype('double')).apply(lambda x: classify_two(x))
    df['class'] = df['class'].shift(-1)
    
    df = df.dropna()
    
#     df['Open'] = df['Open']/df['Close']
    
    df = df.drop('Open', axis=1)
    df = df.drop('High', axis=1)
    df = df.drop('Low', axis=1)
    df = df.drop('Close', axis=1)
    df = df.drop('Volume', axis=1)
    
    df = df.set_index('Datetime')
    
    
    return df



def get_csv(back_hours, hours, money):
    global MULTI
    time = datetime.datetime.now() 
    
    df = get_now_data(time, period_hours=hours, money=money, foot = FOOT , back_hours=back_hours, times=MULTI)
    date_to = (time+datetime.timedelta(hours=-back_hours)+datetime.timedelta(seconds=-1)).strftime("%Y-%m-%d")
    date_from = (time + datetime.timedelta(hours=-hours)+datetime.timedelta(hours=-back_hours)).strftime("%Y-%m-%d")
    df.to_csv("csv/"+str(money)+"_"+ date_from + "_" + date_to +"_"+str(hours)+'.csv', mode = 'w')
    print('"'+str(money)+"_"+ date_from + "_" + date_to +"_"+str(hours*MULTI)+'.csv', end='", ')
    
    return df

def get_moneys_csv(back_hours, hours, moneylist):
    csvlist = []
    
    time = datetime.datetime.now()
    date_to = (time+datetime.timedelta(hours=-back_hours)+datetime.timedelta(seconds=-1)).strftime("%Y-%m-%d")
    date_from = (time + datetime.timedelta(hours=-hours)+datetime.timedelta(hours=-back_hours)).strftime("%Y-%m-%d")
    
    for i in range (len(moneylist)):
        get_csv(back_hours, hours, money=moneylist[i])
        csvlist.extend([str(moneylist[i])+"_"+ date_from + "_" + date_to +"_"+str(hours)+'.csv'])
    
    return csvlist
        
def classify_two(x):
        if x<0:
            return -1
        elif 0<=x:
            return 1
        
def classify_random(x):
        ram = random.randint(0,1)
        if ram==0:
            return -1
        elif ram==1:
            return 1
        

def get_int_csv(moneylist):
    global TERM, DNUM
    shutil.rmtree('csv')
    os.mkdir('csv')
    array = get_moneys_csv(back_hours=TERM, hours=DNUM, moneylist = moneylist)
    return array

def make_bins(max_num, min_num, bin_num):
    global DIVIDE
    delta = max_num-min_num
    delta = delta/(DIVIDE-1)
    bins = []
    povit = min_num
    for i in range(DIVIDE-1):
        povit += delta
        bins.extend([povit])
#     print(bins)
    return bins

def digitize_data(df):
    bin_num = len(df)
    for i in range(len(df.columns)):
        col = df.columns.values.tolist()[i]
        if col == "class":
            continue
        elif col == "true":
            continue
        else:
            max_num = df[col].max()
            min_num = df[col].min()
            df[col] = np.digitize(df[col], make_bins(max_num, min_num, bin_num))
    return df

def grider(dataname):
    df = pd.read_csv("csv/"+dataname, index_col='Datetime')
    df = digitize_data(df)
#     print(df)
    return df
    
def make_table(line, money):
    global DIVIDE
    count = 0
    df = grider(money)
    print("Table data")
    print(df.head(1).index.values, end=' to ')
    print(df.tail(1).index.values)

    table = np.zeros((DIVIDE,DIVIDE,DIVIDE,DIVIDE,DIVIDE,DIVIDE))
    for y in range(len(df)):
        temp = []
        for x in range(len(df.columns)-1):
            temp.extend([df.iat[y,x]])
        table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]] += int(df.iat[y,len(df.columns)-1])
        count += 1
    print("Beyond LINE: ", end='')
    print(np.count_nonzero(table>line)/np.count_nonzero(table!=0))
    print("table count: "+str(count))
    return table

def buy_test(table, money):
    global FOOT, TERM, LINE, POSSESTION, PAY, PAYOUT, WIN, LOSE, COUNT
    df_now = get_now_data(datetime.datetime.now(), TERM, money, FOOT, back_hours = 0, times = 0)
#     df_now['class'] = df_now['class'].shift(1)
    df_now = digitize_data(df_now)
    df_now = df_now.dropna()
    print("")
    print("test data")
    print(df_now.head(1).index.values,end=' to ')
    print(df_now.tail(1).index.values)
    count = [0,0,0]
    win = 0
    lose = 0
    glaph = []
    pos = POSSESTION
    history = []
    for y in range(len(df_now)):
        temp = []
        for x in range(len(df_now.columns)-1):
            temp.extend([df_now.iat[y,x]])
        value = table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]]
        if value>=LINE: #HIGH予想
            count[0] += 1
            pos -= PAY
            if(int(df_now.iat[y,len(df_now.columns)-1])>0): #実際HIGHなら
                pos += PAY*PAYOUT
                win += 1
                history.extend([0.9])
            else:
                lose += 1
                history.extend([-1])
#                 table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]] = 0 #never use this cell
                table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]] = -1*table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]]
                continue
        elif value<=-LINE: #LOW予想
            count[1] += 1
            pos -= PAY
            if(int(df_now.iat[y,len(df_now.columns)-1])<0): #実際LOWなら
                pos += PAY*PAYOUT
                win += 1
                history.extend([0.9])
            else:
                lose += 1
                history.extend([-1])
#                 table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]] = 0 #never use this cell
                table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]] = -1*table[temp[0]][temp[1]][temp[2]][temp[3]][temp[4]][temp[5]]
                continue
        else:
            count[2] += 1
            history.extend([0])
        glaph.extend([pos])
    print("HIGH/LOW/STAY")
    print(count)
    print("win: "+str(win))
    print("lose: "+str(lose))
    
    WIN += win
    LOSE += lose
    COUNT += sum(count)
    
    if(win+lose==0):
        print("No Trade")
    else:
        print("Rate: "+str(win/(win+lose)))
    print("Posesstion: "+str(pos))
    POSSESTION += pos - POSSESTION
    
#     POSSESTION = 10000
    
#     if(POSSESTION < 0):
#         sys.exit()
#     plt.plot(list(range(0,len(glaph))), glaph)
#     plt.show()

    return win,lose, history

def main():
    global LINE, POSSESTION
    array = get_int_csv(MONEYS)
    w = 0
    l = 0
    for i in range(len(array)):
        print("")
        print("-----------------------")
        print(MONEYS[i])
        table = make_table(LINE, array[i])
        win, lose, history = buy_test(table, MONEYS[i])
        w += win
        l += lose
#         with open('result.csv', 'a') as f:
#             writer = csv.writer(f)
#             writer.writerow([MONEYS[i], history])
    print("RESULT: "+str(POSSESTION))
    RESULT.extend([POSSESTION])
#     with open('result.csv', 'a') as f:
#         writer = csv.writer(f)
# #         writer.writerow([money, pos])
#         writer.writerow([POSSESTION, w/(w+l)])
    

FOOT = 'H1'
DNUM = 100
MULTI = 1  #datanum = DNUM * MULTI
DIVIDE = 6  #GRIDの数
LINE = 2  #トレードのライン(LINE以上，以下の時エントリー)
TERM = 100  #テスト期間
PAY = 1000  #支払額
PAYOUT = 1.9 #ペイアウト率
POSSESTION = 10000 #所持金
BACK = 0
RESULT = []
WIN = 0
LOSE = 0
COUNT = 0

MONEYS = [
        'AUD_JPY',
    
#         'AUD_NZD',
#         'AUD_USD',
#         'CAD_JPY',
#         'CHF_JPY',
#         'EUR_AUD',
#         'EUR_GBP',
    
        'EUR_JPY',
        'EUR_USD',
    
#         'GBP_AUD',
    
        'GBP_JPY',
    
#         'GBP_USD',
#         'NZD_JPY',
#         'NZD_USD',
#         'USD_CAD',
#         'USD_CHF',
        'USD_JPY'
    ]

# MONEYS = [
#         'AUD_JPY',
#         'AUD_NZD',
#         'AUD_USD',
#         'CAD_JPY',
#         'CHF_JPY',
#         'EUR_AUD',
#         'EUR_GBP',
#         'EUR_JPY',
#         'EUR_USD',
#         'GBP_AUD',
#         'GBP_JPY',
#         'GBP_USD',
#         'NZD_JPY',
#         'NZD_USD',
#         'USD_CAD',
#         'USD_CHF',
#         'USD_JPY'
#     ]

# for x in range(100):
#     print("")
#     print("TEST: "+ str(x))
#     main()
#     BACK += TERM
#     print("Trade/Trade chance: "+str(WIN+LOSE)+"/"+str(COUNT))
#     print("Trade rate: "+str((WIN+LOSE)/COUNT))
#     print("Rate: "+str(WIN/(WIN+LOSE)))

DNUM = 100
DIVIDE = 2
BEST = 0
for i in range(10):
    for j in range(7):
        print("DNUM:"+str(DNUM)+" /DIVIDE:"+str(DIVIDE)+" /BEST:"+str(BEST))
        for x in range(10):
            print("")
            print("TEST: "+ str(x))
            main()
            BACK += TERM
            if(LOSE==0 and WIN==0):
                LOSE = 1
            print("Trade/Trade chance: "+str(WIN+LOSE)+"/"+str(COUNT))
            print("Trade rate: "+str((WIN+LOSE)/COUNT))
            print("Rate: "+str(WIN/(WIN+LOSE)))
        with open('result.csv', 'a') as f:
                writer = csv.writer(f)
                if(BEST<WIN/(WIN+LOSE)):
                    BEST = WIN/(WIN+LOSE)
                    writer.writerow(["BEST", DNUM, DIVIDE, WIN/(WIN+LOSE), POSSESTION])
                else:
                    writer.writerow([DNUM, DIVIDE, WIN/(WIN+LOSE), POSSESTION])
        WIN = 0
        LOSE = 0
        POSSESTION = 10000
        BACK = 0
        COUNT = 0
        DIVIDE += 1
    DNUM+=100
    DIVIDE = 2
    BACK = 0
# Out:
# DNUM:100 /DIVIDE:2 /BEST:0
#
# TEST: 0
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [34, 25, 4]
# win: 31
# lose: 28
# Rate: 0.5254237288135594
# Posesstion: 9900.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [31, 28, 4]
# win: 29
# lose: 30
# Rate: 0.4915254237288136
# Posesstion: 6000.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.16666666666666666
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [32, 28, 3]
# win: 28
# lose: 32
# Rate: 0.4666666666666667
# Posesstion: -800.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.25
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [31, 30, 2]
# win: 38
# lose: 23
# Rate: 0.6229508196721312
# Posesstion: 10400.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [36, 24, 3]
# win: 33
# lose: 27
# Rate: 0.55
# Posesstion: 13100.0
# RESULT: 13100.0
# Trade/Trade chance: 299/315
# Trade rate: 0.9492063492063492
# Rate: 0.5317725752508361
#
# TEST: 1
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [17, 23, 3]
# win: 25
# lose: 15
# Rate: 0.625
# Posesstion: 20600.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [20, 19, 4]
# win: 19
# lose: 20
# Rate: 0.48717948717948717
# Posesstion: 17700.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [24, 15, 4]
# win: 24
# lose: 15
# Rate: 0.6153846153846154
# Posesstion: 24300.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.25
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [25, 16, 2]
# win: 19
# lose: 22
# Rate: 0.4634146341463415
# Posesstion: 19400.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.2
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [19, 20, 4]
# win: 21
# lose: 18
# Rate: 0.5384615384615384
# Posesstion: 20300.0
# RESULT: 20300.0
# Trade/Trade chance: 497/530
# Trade rate: 0.9377358490566038
# Rate: 0.5372233400402414
#
# TEST: 2
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.25
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [40, 47, 4]
# win: 42
# lose: 45
# Rate: 0.4827586206896552
# Posesstion: 13100.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.0
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [0, 0, 91]
# win: 0
# lose: 0
# No Trade
# Posesstion: 13100.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.3333333333333333
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [43, 44, 4]
# win: 48
# lose: 39
# Rate: 0.5517241379310345
# Posesstion: 17300.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.2
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [43, 44, 4]
# win: 43
# lose: 44
# Rate: 0.4942528735632184
# Posesstion: 12000.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.25
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [45, 42, 4]
# win: 39
# lose: 48
# Rate: 0.4482758620689655
# Posesstion: -900.0
# RESULT: -900.0
# Trade/Trade chance: 845/985
# Trade rate: 0.8578680203045685
# Rate: 0.5195266272189349
#
# TEST: 3
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.25
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [23, 16, 4]
# win: 20
# lose: 19
# Rate: 0.5128205128205128
# Posesstion: -1900.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.0
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [21, 20, 2]
# win: 21
# lose: 20
# Rate: 0.5121951219512195
# Posesstion: -3000.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.16666666666666666
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [19, 22, 2]
# win: 14
# lose: 27
# Rate: 0.34146341463414637
# Posesstion: -17400.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.2
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [22, 18, 3]
# win: 19
# lose: 21
# Rate: 0.475
# Posesstion: -21300.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.0
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: -21300.0
# RESULT: -21300.0
# Trade/Trade chance: 1006/1200
# Trade rate: 0.8383333333333334
# Rate: 0.5099403578528827
#
# TEST: 4
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.25
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [42, 30, 2]
# win: 41
# lose: 31
# Rate: 0.5694444444444444
# Posesstion: -15400.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.25
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [36, 34, 4]
# win: 41
# lose: 29
# Rate: 0.5857142857142857
# Posesstion: -7500.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.16666666666666666
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [39, 33, 2]
# win: 35
# lose: 37
# Rate: 0.4861111111111111
# Posesstion: -13000.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.2
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [39, 31, 4]
# win: 42
# lose: 28
# Rate: 0.6
# Posesstion: -3200.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.0
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [37, 33, 4]
# win: 37
# lose: 33
# Rate: 0.5285714285714286
# Posesstion: -2900.0
# RESULT: -2900.0
# Trade/Trade chance: 1360/1570
# Trade rate: 0.8662420382165605
# Rate: 0.5213235294117647
#
# TEST: 5
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.3333333333333333
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [18, 13, 4]
# win: 12
# lose: 19
# Rate: 0.3870967741935484
# Posesstion: -11100.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.0
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [16, 16, 3]
# win: 17
# lose: 15
# Rate: 0.53125
# Posesstion: -10800.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.0
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [0, 0, 35]
# win: 0
# lose: 0
# No Trade
# Posesstion: -10800.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.25
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [22, 9, 4]
# win: 18
# lose: 13
# Rate: 0.5806451612903226
# Posesstion: -7600.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 06:00']
# Beyond LINE: 0.25
# table count: 120
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [15, 15, 5]
# win: 8
# lose: 22
# Rate: 0.26666666666666666
# Posesstion: -22400.0
# RESULT: -22400.0
# Trade/Trade chance: 1484/1745
# Trade rate: 0.8504297994269341
# Rate: 0.5148247978436657
#
# TEST: 6
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.2
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [20, 18, 4]
# win: 18
# lose: 20
# Rate: 0.47368421052631576
# Posesstion: -26200.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.0
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [21, 19, 2]
# win: 17
# lose: 23
# Rate: 0.425
# Posesstion: -33900.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.2
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [24, 15, 3]
# win: 17
# lose: 22
# Rate: 0.4358974358974359
# Posesstion: -40600.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.2
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [23, 16, 3]
# win: 15
# lose: 24
# Rate: 0.38461538461538464
# Posesstion: -51100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.25
# table count: 121
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [18, 20, 4]
# win: 15
# lose: 23
# Rate: 0.39473684210526316
# Posesstion: -60600.0
# RESULT: -60600.0
# Trade/Trade chance: 1678/1955
# Trade rate: 0.858312020460358
# Rate: 0.5041716328963052
#
# TEST: 7
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.25
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [39, 26, 2]
# win: 31
# lose: 34
# Rate: 0.47692307692307695
# Posesstion: -66700.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.0
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [26, 36, 5]
# win: 23
# lose: 39
# Rate: 0.3709677419354839
# Posesstion: -85000.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.2
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [28, 36, 3]
# win: 26
# lose: 38
# Rate: 0.40625
# Posesstion: -99600.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.2
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [39, 25, 3]
# win: 30
# lose: 34
# Rate: 0.46875
# Posesstion: -106600.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.0
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 06:00']
# HIGH/LOW/STAY
# [35, 30, 3]
# win: 32
# lose: 33
# Rate: 0.49230769230769234
# Posesstion: -110800.0
# RESULT: -110800.0
# Trade/Trade chance: 1998/2291
# Trade rate: 0.872108249672632
# Rate: 0.4944944944944945
#
# TEST: 8
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.25
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [22, 18, 3]
# win: 19
# lose: 21
# Rate: 0.475
# Posesstion: -114700.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.25
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [18, 21, 4]
# win: 16
# lose: 23
# Rate: 0.41025641025641024
# Posesstion: -123300.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.25
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [23, 16, 4]
# win: 17
# lose: 22
# Rate: 0.4358974358974359
# Posesstion: -130000.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.2
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [20, 19, 4]
# win: 16
# lose: 23
# Rate: 0.41025641025641024
# Posesstion: -138600.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.0
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [20, 19, 4]
# win: 19
# lose: 20
# Rate: 0.48717948717948717
# Posesstion: -141500.0
# RESULT: -141500.0
# Trade/Trade chance: 2194/2506
# Trade rate: 0.8754988028731046
# Rate: 0.48997265268915224
#
# TEST: 9
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.25
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [39, 37, 2]
# win: 35
# lose: 41
# Rate: 0.4605263157894737
# Posesstion: -151000.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.2
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [37, 38, 3]
# win: 36
# lose: 39
# Rate: 0.48
# Posesstion: -157600.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.2
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [42, 34, 2]
# win: 38
# lose: 38
# Rate: 0.5
# Posesstion: -161400.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.3333333333333333
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [40, 33, 5]
# win: 30
# lose: 43
# Rate: 0.410958904109589
# Posesstion: -177400.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.25
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [26, 49, 3]
# win: 35
# lose: 40
# Rate: 0.4666666666666667
# Posesstion: -185900.0
# RESULT: -185900.0
# Trade/Trade chance: 2569/2896
# Trade rate: 0.887085635359116
# Rate: 0.4861813935383418
# DNUM:100 /DIVIDE:3 /BEST:0.4861813935383418
#
# TEST: 0
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [14, 12, 37]
# win: 10
# lose: 16
# Rate: 0.38461538461538464
# Posesstion: 3000.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.07692307692307693
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [9, 12, 42]
# win: 16
# lose: 5
# Rate: 0.7619047619047619
# Posesstion: 12400.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.09523809523809523
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [3, 5, 55]
# win: 5
# lose: 3
# Rate: 0.625
# Posesstion: 13900.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.18181818181818182
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [12, 7, 44]
# win: 10
# lose: 9
# Rate: 0.5263157894736842
# Posesstion: 13900.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.1
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [4, 4, 55]
# win: 3
# lose: 5
# Rate: 0.375
# Posesstion: 11600.0
# RESULT: 11600.0
# Trade/Trade chance: 82/3211
# Trade rate: 0.02553721582061663
# Rate: 0.5365853658536586
#
# TEST: 1
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.08695652173913043
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [8, 14, 21]
# win: 16
# lose: 6
# Rate: 0.7272727272727273
# Posesstion: 20000.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [15, 12, 16]
# win: 14
# lose: 13
# Rate: 0.5185185185185185
# Posesstion: 19600.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [1, 4, 38]
# win: 1
# lose: 4
# Rate: 0.2
# Posesstion: 16500.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [6, 2, 35]
# win: 5
# lose: 3
# Rate: 0.625
# Posesstion: 18000.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.17391304347826086
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [18, 13, 12]
# win: 18
# lose: 13
# Rate: 0.5806451612903226
# Posesstion: 21200.0
# RESULT: 21200.0
# Trade/Trade chance: 175/3426
# Trade rate: 0.05107997664915353
# Rate: 0.56
#
# TEST: 2
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.16666666666666666
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [7, 11, 73]
# win: 11
# lose: 7
# Rate: 0.6111111111111112
# Posesstion: 24100.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.08333333333333333
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [15, 17, 59]
# win: 16
# lose: 16
# Rate: 0.5
# Posesstion: 22500.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.08333333333333333
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [12, 14, 65]
# win: 13
# lose: 13
# Rate: 0.5
# Posesstion: 21200.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.16666666666666666
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [25, 20, 46]
# win: 20
# lose: 25
# Rate: 0.4444444444444444
# Posesstion: 14200.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.16666666666666666
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [28, 28, 35]
# win: 25
# lose: 31
# Rate: 0.44642857142857145
# Posesstion: 5700.0
# RESULT: 5700.0
# Trade/Trade chance: 352/3881
# Trade rate: 0.09069827364081422
# Rate: 0.5198863636363636
#
# TEST: 3
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.2
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [18, 6, 19]
# win: 13
# lose: 11
# Rate: 0.5416666666666666
# Posesstion: 6400.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.1
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [9, 10, 24]
# win: 10
# lose: 9
# Rate: 0.5263157894736842
# Posesstion: 6400.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.125
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [11, 6, 26]
# win: 6
# lose: 11
# Rate: 0.35294117647058826
# Posesstion: 800.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.125
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [11, 8, 24]
# win: 9
# lose: 10
# Rate: 0.47368421052631576
# Posesstion: -1100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.0625
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [8, 6, 29]
# win: 6
# lose: 8
# Rate: 0.42857142857142855
# Posesstion: -3700.0
# RESULT: -3700.0
# Trade/Trade chance: 445/4096
# Trade rate: 0.108642578125
# Rate: 0.5101123595505618
#
# TEST: 4
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.2222222222222222
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [14, 9, 51]
# win: 14
# lose: 9
# Rate: 0.6086956521739131
# Posesstion: -100.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.05555555555555555
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [14, 8, 52]
# win: 9
# lose: 13
# Rate: 0.4090909090909091
# Posesstion: -5000.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.17647058823529413
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [19, 16, 39]
# win: 16
# lose: 19
# Rate: 0.45714285714285713
# Posesstion: -9600.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.2
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [22, 12, 40]
# win: 17
# lose: 17
# Rate: 0.5
# Posesstion: -11300.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.05555555555555555
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [23, 24, 27]
# win: 22
# lose: 25
# Rate: 0.46808510638297873
# Posesstion: -16500.0
# RESULT: -16500.0
# Trade/Trade chance: 606/4466
# Trade rate: 0.13569189431258397
# Rate: 0.5033003300330033
#
# TEST: 5
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.16666666666666666
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [3, 1, 31]
# win: 2
# lose: 2
# Rate: 0.5
# Posesstion: -16700.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.06666666666666667
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [3, 2, 30]
# win: 4
# lose: 1
# Rate: 0.8
# Posesstion: -14100.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.2222222222222222
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [17, 8, 10]
# win: 15
# lose: 10
# Rate: 0.6
# Posesstion: -10600.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.2727272727272727
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [5, 4, 26]
# win: 8
# lose: 1
# Rate: 0.8888888888888888
# Posesstion: -4400.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 06:00']
# Beyond LINE: 0.09523809523809523
# table count: 120
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [15, 8, 12]
# win: 11
# lose: 12
# Rate: 0.4782608695652174
# Posesstion: -6500.0
# RESULT: -6500.0
# Trade/Trade chance: 672/4641
# Trade rate: 0.14479638009049775
# Rate: 0.5133928571428571
#
# TEST: 6
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.15384615384615385
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [1, 2, 39]
# win: 1
# lose: 2
# Rate: 0.3333333333333333
# Posesstion: -7600.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.0
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [7, 5, 30]
# win: 6
# lose: 6
# Rate: 0.5
# Posesstion: -8200.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.15789473684210525
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [13, 11, 18]
# win: 12
# lose: 12
# Rate: 0.5
# Posesstion: -9400.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.1
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [2, 1, 39]
# win: 2
# lose: 1
# Rate: 0.6666666666666666
# Posesstion: -8600.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.18181818181818182
# table count: 121
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [3, 1, 38]
# win: 2
# lose: 2
# Rate: 0.5
# Posesstion: -8800.0
# RESULT: -8800.0
# Trade/Trade chance: 718/4851
# Trade rate: 0.14801071943929087
# Rate: 0.5125348189415042
#
# TEST: 7
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.1111111111111111
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [6, 1, 60]
# win: 5
# lose: 2
# Rate: 0.7142857142857143
# Posesstion: -6300.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.0
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [9, 15, 43]
# win: 13
# lose: 11
# Rate: 0.5416666666666666
# Posesstion: -5600.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.2
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [8, 6, 53]
# win: 5
# lose: 9
# Rate: 0.35714285714285715
# Posesstion: -10100.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.07142857142857142
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [13, 8, 46]
# win: 10
# lose: 11
# Rate: 0.47619047619047616
# Posesstion: -12100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.07692307692307693
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 06:00']
# HIGH/LOW/STAY
# [19, 15, 34]
# win: 19
# lose: 15
# Rate: 0.5588235294117647
# Posesstion: -10000.0
# RESULT: -10000.0
# Trade/Trade chance: 818/5187
# Trade rate: 0.15770194717563138
# Rate: 0.5134474327628362
#
# TEST: 8
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.2222222222222222
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [3, 0, 40]
# win: 2
# lose: 1
# Rate: 0.6666666666666666
# Posesstion: -9200.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.16666666666666666
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [13, 11, 19]
# win: 13
# lose: 11
# Rate: 0.5416666666666666
# Posesstion: -8500.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.23076923076923078
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [10, 8, 25]
# win: 9
# lose: 9
# Rate: 0.5
# Posesstion: -9400.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.1
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [13, 12, 18]
# win: 7
# lose: 18
# Rate: 0.28
# Posesstion: -21100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.0
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [5, 11, 27]
# win: 7
# lose: 9
# Rate: 0.4375
# Posesstion: -23800.0
# RESULT: -23800.0
# Trade/Trade chance: 904/5402
# Trade rate: 0.16734542761940022
# Rate: 0.5066371681415929
#
# TEST: 9
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.2
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [6, 7, 65]
# win: 7
# lose: 6
# Rate: 0.5384615384615384
# Posesstion: -23500.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.15789473684210525
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [12, 15, 51]
# win: 13
# lose: 14
# Rate: 0.48148148148148145
# Posesstion: -25800.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.10526315789473684
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [19, 13, 46]
# win: 12
# lose: 20
# Rate: 0.375
# Posesstion: -35000.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.16666666666666666
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [11, 11, 56]
# win: 6
# lose: 16
# Rate: 0.2727272727272727
# Posesstion: -45600.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.14285714285714285
# table count: 111
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [15, 36, 27]
# win: 22
# lose: 29
# Rate: 0.43137254901960786
# Posesstion: -54800.0
# RESULT: -54800.0
# Trade/Trade chance: 1049/5792
# Trade rate: 0.18111187845303867
# Rate: 0.4938036224976168
# DNUM:100 /DIVIDE:4 /BEST:0.4938036224976168
#
# TEST: 0
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.0
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [11, 8, 44]
# win: 11
# lose: 8
# Rate: 0.5789473684210527
# Posesstion: 11900.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.06451612903225806
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [0, 1, 62]
# win: 1
# lose: 0
# Rate: 1.0
# Posesstion: 12800.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.06666666666666667
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [14, 10, 39]
# win: 10
# lose: 14
# Rate: 0.4166666666666667
# Posesstion: 7800.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.14285714285714285
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [12, 12, 39]
# win: 9
# lose: 15
# Rate: 0.375
# Posesstion: 900.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-18 11:00'] to ['2021-01-16 01:00']
# Beyond LINE: 0.05555555555555555
# table count: 144
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [6, 2, 55]
# win: 3
# lose: 5
# Rate: 0.375
# Posesstion: -1400.0
# RESULT: -1400.0
# Trade/Trade chance: 76/6107
# Trade rate: 0.012444735549369576
# Rate: 0.4473684210526316
#
# TEST: 1
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.06060606060606061
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: -1400.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.09090909090909091
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [7, 7, 29]
# win: 9
# lose: 5
# Rate: 0.6428571428571429
# Posesstion: 1700.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.10526315789473684
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [2, 1, 40]
# win: 3
# lose: 0
# Rate: 1.0
# Posesstion: 4400.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.08
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [6, 6, 31]
# win: 5
# lose: 7
# Rate: 0.4166666666666667
# Posesstion: 1900.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-12 07:00'] to ['2021-01-11 21:00']
# Beyond LINE: 0.07894736842105263
# table count: 144
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [1, 0, 42]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 900.0
# RESULT: 900.0
# Trade/Trade chance: 106/6322
# Trade rate: 0.01676684593483075
# Rate: 0.4811320754716981
#
# TEST: 2
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.05714285714285714
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [5, 7, 79]
# win: 9
# lose: 3
# Rate: 0.75
# Posesstion: 6000.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.05405405405405406
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [9, 10, 72]
# win: 10
# lose: 9
# Rate: 0.5263157894736842
# Posesstion: 6000.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.09090909090909091
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [12, 12, 67]
# win: 13
# lose: 11
# Rate: 0.5416666666666666
# Posesstion: 6700.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.06451612903225806
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [15, 15, 61]
# win: 16
# lose: 14
# Rate: 0.5333333333333333
# Posesstion: 7100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-08 03:00'] to ['2021-01-07 17:00']
# Beyond LINE: 0.1111111111111111
# table count: 127
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [3, 1, 87]
# win: 3
# lose: 1
# Rate: 0.75
# Posesstion: 8800.0
# RESULT: 8800.0
# Trade/Trade chance: 195/6777
# Trade rate: 0.02877379371403276
# Rate: 0.5230769230769231
#
# TEST: 3
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.23076923076923078
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [7, 1, 35]
# win: 6
# lose: 2
# Rate: 0.75
# Posesstion: 12200.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.10344827586206896
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [3, 1, 39]
# win: 1
# lose: 3
# Rate: 0.25
# Posesstion: 10100.0
#
# -----------------------
# EUR_USD
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.06521739130434782
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [5, 7, 31]
# win: 5
# lose: 7
# Rate: 0.4166666666666667
# Posesstion: 7600.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.11428571428571428
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [11, 3, 29]
# win: 9
# lose: 5
# Rate: 0.6428571428571429
# Posesstion: 10700.0
#
# -----------------------
# USD_JPY
# Table data
# ['2021-01-04 16:00'] to ['2021-01-01 05:00']
# Beyond LINE: 0.05555555555555555
# table count: 119
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [5, 2, 36]
# win: 3
# lose: 4
# Rate: 0.42857142857142855
# Posesstion: 9400.0
# RESULT: 9400.0
# Trade/Trade chance: 240/6992
# Trade rate: 0.034324942791762014
# Rate: 0.525
#
# TEST: 4
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.0
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [7, 3, 64]
# win: 5
# lose: 5
# Rate: 0.5
# Posesstion: 8900.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.15625
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [7, 6, 61]
# win: 6
# lose: 7
# Rate: 0.46153846153846156
# Posesstion: 7300.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.09090909090909091
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [7, 5, 62]
# win: 10
# lose: 2
# Rate: 0.8333333333333334
# Posesstion: 14300.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.10344827586206896
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [16, 6, 52]
# win: 16
# lose: 6
# Rate: 0.7272727272727273
# Posesstion: 22700.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-30 19:00'] to ['2020-12-30 09:00']
# Beyond LINE: 0.08108108108108109
# table count: 87
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [12, 18, 44]
# win: 9
# lose: 21
# Rate: 0.3
# Posesstion: 9800.0
# RESULT: 9800.0
# Trade/Trade chance: 327/7362
# Trade rate: 0.044417277913610435
# Rate: 0.5259938837920489
#
# TEST: 5
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.05714285714285714
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [2, 1, 32]
# win: 1
# lose: 2
# Rate: 0.3333333333333333
# Posesstion: 8700.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.02564102564102564
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [2, 1, 32]
# win: 0
# lose: 3
# Rate: 0.0
# Posesstion: 5700.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.12903225806451613
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [7, 4, 24]
# win: 6
# lose: 5
# Rate: 0.5454545454545454
# Posesstion: 6100.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 05:00']
# Beyond LINE: 0.07894736842105263
# table count: 119
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [0, 1, 34]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 5100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-28 16:00'] to ['2020-12-25 06:00']
# Beyond LINE: 0.02857142857142857
# table count: 120
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [4, 4, 27]
# win: 2
# lose: 6
# Rate: 0.25
# Posesstion: 900.0
# RESULT: 900.0
# Trade/Trade chance: 353/7537
# Trade rate: 0.04683561098580337
# Rate: 0.5127478753541076
#
# TEST: 6
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.14814814814814814
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [2, 0, 40]
# win: 2
# lose: 0
# Rate: 1.0
# Posesstion: 2700.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.025
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [3, 8, 31]
# win: 7
# lose: 4
# Rate: 0.6363636363636364
# Posesstion: 5000.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.06666666666666667
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [8, 5, 29]
# win: 6
# lose: 7
# Rate: 0.46153846153846156
# Posesstion: 3400.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.16216216216216217
# table count: 120
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [3, 2, 37]
# win: 3
# lose: 2
# Rate: 0.6
# Posesstion: 4100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-22 11:00'] to ['2020-12-22 01:00']
# Beyond LINE: 0.08695652173913043
# table count: 121
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [0, 0, 42]
# win: 0
# lose: 0
# No Trade
# Posesstion: 4100.0
# RESULT: 4100.0
# Trade/Trade chance: 384/7747
# Trade rate: 0.04956757454498516
# Rate: 0.5182291666666666
#
# TEST: 7
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.03125
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [4, 5, 58]
# win: 3
# lose: 6
# Rate: 0.3333333333333333
# Posesstion: 800.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.02857142857142857
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [12, 17, 38]
# win: 15
# lose: 14
# Rate: 0.5172413793103449
# Posesstion: 300.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.12903225806451613
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [16, 23, 28]
# win: 18
# lose: 21
# Rate: 0.46153846153846156
# Posesstion: -4500.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.06060606060606061
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [13, 11, 43]
# win: 10
# lose: 14
# Rate: 0.4166666666666667
# Posesstion: -9500.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-18 07:00'] to ['2020-12-17 21:00']
# Beyond LINE: 0.0
# table count: 131
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 06:00']
# HIGH/LOW/STAY
# [2, 5, 61]
# win: 3
# lose: 4
# Rate: 0.42857142857142855
# Posesstion: -10800.0
# RESULT: -10800.0
# Trade/Trade chance: 492/8083
# Trade rate: 0.06086848942224422
# Rate: 0.5040650406504065
#
# TEST: 8
# "AUD_JPY_2021-01-16_2021-01-20_100.csv", "EUR_JPY_2021-01-16_2021-01-20_100.csv", "EUR_USD_2021-01-16_2021-01-20_100.csv", "GBP_JPY_2021-01-16_2021-01-20_100.csv", "USD_JPY_2021-01-16_2021-01-20_100.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.125
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [2, 1, 40]
# win: 1
# lose: 2
# Rate: 0.3333333333333333
# Posesstion: -11900.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.09090909090909091
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [6, 6, 31]
# win: 3
# lose: 9
# Rate: 0.25
# Posesstion: -18200.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.0625
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [7, 6, 30]
# win: 7
# lose: 6
# Rate: 0.5384615384615384
# Posesstion: -17900.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-14 16:00'] to ['2020-12-12 05:00']
# Beyond LINE: 0.04878048780487805
# table count: 143
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [5, 6, 32]
# win: 5
# lose: 6
# Rate: 0.45454545454545453
# Posesstion: -19400.0
#
# -----------------------
# USD_JPY
# ...
# table count: 1368
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [0, 0, 63]
# win: 0
# lose: 0
# No Trade
# Posesstion: 10000
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.15
# table count: 1368
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [0, 0, 63]
# win: 0
# lose: 0
# No Trade
# Posesstion: 10000
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.22641509433962265
# table count: 1368
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [1, 0, 62]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 9000
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.14814814814814814
# table count: 1368
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [0, 1, 62]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 8000
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-09 23:00'] to ['2020-12-09 13:00']
# Beyond LINE: 0.07017543859649122
# table count: 1369
#
# test data
# ['2021-01-20 15:00'] to ['2021-01-23 05:00']
# HIGH/LOW/STAY
# [0, 0, 63]
# win: 0
# lose: 0
# No Trade
# Posesstion: 8000
# RESULT: 8000
# Trade/Trade chance: 2/200139
# Trade rate: 9.993054826895308e-06
# Rate: 0.0
#
# TEST: 1
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-07 16:00'] to ['2020-12-05 05:00']
# Beyond LINE: 0.17777777777777778
# table count: 1378
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: 8000
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-07 16:00'] to ['2020-12-05 05:00']
# Beyond LINE: 0.10810810810810811
# table count: 1378
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: 8000
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-07 16:00'] to ['2020-12-05 05:00']
# Beyond LINE: 0.16346153846153846
# table count: 1378
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [1, 0, 42]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 7000
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-07 16:00'] to ['2020-12-05 05:00']
# Beyond LINE: 0.15
# table count: 1378
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: 7000
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-07 16:00'] to ['2020-12-05 05:00']
# Beyond LINE: 0.06936416184971098
# table count: 1379
#
# test data
# ['2021-01-18 11:00'] to ['2021-01-20 05:00']
# HIGH/LOW/STAY
# [1, 4, 38]
# win: 2
# lose: 3
# Rate: 0.4
# Posesstion: 5800.0
# RESULT: 5800.0
# Trade/Trade chance: 8/200354
# Trade rate: 3.992932509458259e-05
# Rate: 0.25
#
# TEST: 2
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-12-01 15:00'] to ['2020-12-01 05:00']
# Beyond LINE: 0.24242424242424243
# table count: 1368
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [0, 0, 91]
# win: 0
# lose: 0
# No Trade
# Posesstion: 5800.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-12-01 15:00'] to ['2020-12-01 05:00']
# Beyond LINE: 0.15053763440860216
# table count: 1368
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [2, 3, 86]
# win: 2
# lose: 3
# Rate: 0.4
# Posesstion: 4600.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-12-01 15:00'] to ['2020-12-01 05:00']
# Beyond LINE: 0.1746031746031746
# table count: 1368
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [0, 0, 91]
# win: 0
# lose: 0
# No Trade
# Posesstion: 4600.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-12-01 15:00'] to ['2020-12-01 05:00']
# Beyond LINE: 0.12631578947368421
# table count: 1368
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [0, 0, 91]
# win: 0
# lose: 0
# No Trade
# Posesstion: 4600.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-12-01 15:00'] to ['2020-12-01 05:00']
# Beyond LINE: 0.04285714285714286
# table count: 1369
#
# test data
# ['2021-01-12 07:00'] to ['2021-01-16 01:00']
# HIGH/LOW/STAY
# [1, 0, 90]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 3600.0
# RESULT: 3600.0
# Trade/Trade chance: 14/200809
# Trade rate: 6.971799072750723e-05
# Rate: 0.2857142857142857
#
# TEST: 3
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-11-27 11:00'] to ['2020-11-27 01:00']
# Beyond LINE: 0.19444444444444445
# table count: 1368
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [1, 0, 42]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 2600.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-11-27 11:00'] to ['2020-11-27 01:00']
# Beyond LINE: 0.2
# table count: 1368
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: 2600.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-11-27 11:00'] to ['2020-11-27 01:00']
# Beyond LINE: 0.30303030303030304
# table count: 1368
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: 2600.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-11-27 11:00'] to ['2020-11-27 01:00']
# Beyond LINE: 0.14893617021276595
# table count: 1368
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: 2600.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-11-27 11:00'] to ['2020-11-27 01:00']
# Beyond LINE: 0.06542056074766354
# table count: 1369
#
# test data
# ['2021-01-08 03:00'] to ['2021-01-11 21:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: 2600.0
# RESULT: 2600.0
# Trade/Trade chance: 15/201024
# Trade rate: 7.461795606494747e-05
# Rate: 0.26666666666666666
#
# TEST: 4
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-11-23 16:00'] to ['2020-11-21 05:00']
# Beyond LINE: 0.18571428571428572
# table count: 1382
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [1, 0, 73]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 1600.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-11-23 16:00'] to ['2020-11-21 05:00']
# Beyond LINE: 0.11450381679389313
# table count: 1382
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [4, 3, 67]
# win: 4
# lose: 3
# Rate: 0.5714285714285714
# Posesstion: 2200.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-11-23 16:00'] to ['2020-11-21 05:00']
# Beyond LINE: 0.21052631578947367
# table count: 1382
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [0, 0, 74]
# win: 0
# lose: 0
# No Trade
# Posesstion: 2200.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-11-23 16:00'] to ['2020-11-21 05:00']
# Beyond LINE: 0.15447154471544716
# table count: 1382
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [2, 0, 72]
# win: 1
# lose: 1
# Rate: 0.5
# Posesstion: 2100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-11-23 16:00'] to ['2020-11-21 05:00']
# Beyond LINE: 0.056818181818181816
# table count: 1383
#
# test data
# ['2021-01-04 16:00'] to ['2021-01-07 17:00']
# HIGH/LOW/STAY
# [0, 0, 74]
# win: 0
# lose: 0
# No Trade
# Posesstion: 2100.0
# RESULT: 2100.0
# Trade/Trade chance: 25/201394
# Trade rate: 0.00012413478057936184
# Rate: 0.36
#
# TEST: 5
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-11-19 03:00'] to ['2020-11-18 17:00']
# Beyond LINE: 0.1643835616438356
# table count: 1392
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [0, 0, 35]
# win: 0
# lose: 0
# No Trade
# Posesstion: 2100.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-11-19 03:00'] to ['2020-11-18 17:00']
# Beyond LINE: 0.15789473684210525
# table count: 1392
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [1, 0, 34]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: 1100.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-11-19 03:00'] to ['2020-11-18 17:00']
# Beyond LINE: 0.25
# table count: 1392
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [0, 0, 35]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1100.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-11-19 03:00'] to ['2020-11-18 17:00']
# Beyond LINE: 0.1016949152542373
# table count: 1392
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [0, 0, 35]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1100.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-11-19 03:00'] to ['2020-11-18 17:00']
# Beyond LINE: 0.036585365853658534
# table count: 1393
#
# test data
# ['2020-12-30 19:00'] to ['2021-01-01 05:00']
# HIGH/LOW/STAY
# [0, 0, 35]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1100.0
# RESULT: 1100.0
# Trade/Trade chance: 26/201569
# Trade rate: 0.00012898808844614003
# Rate: 0.34615384615384615
#
# TEST: 6
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-11-16 16:00'] to ['2020-11-14 05:00']
# Beyond LINE: 0.1388888888888889
# table count: 1406
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [0, 2, 40]
# win: 1
# lose: 1
# Rate: 0.5
# Posesstion: 1000.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-11-16 16:00'] to ['2020-11-14 05:00']
# Beyond LINE: 0.12987012987012986
# table count: 1406
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [0, 0, 42]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1000.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-11-16 16:00'] to ['2020-11-14 05:00']
# Beyond LINE: 0.2
# table count: 1406
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [0, 0, 42]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1000.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-11-16 16:00'] to ['2020-11-14 05:00']
# Beyond LINE: 0.12244897959183673
# table count: 1406
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [0, 0, 42]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1000.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-11-16 16:00'] to ['2020-11-14 05:00']
# Beyond LINE: 0.1188118811881188
# table count: 1407
#
# test data
# ['2020-12-28 16:00'] to ['2020-12-30 09:00']
# HIGH/LOW/STAY
# [1, 0, 41]
# win: 1
# lose: 0
# Rate: 1.0
# Posesstion: 1900.0
# RESULT: 1900.0
# Trade/Trade chance: 29/201779
# Trade rate: 0.00014372159640002182
# Rate: 0.3793103448275862
#
# TEST: 7
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-11-10 19:00'] to ['2020-11-10 09:00']
# Beyond LINE: 0.1791044776119403
# table count: 1416
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [0, 0, 67]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1900.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-11-10 19:00'] to ['2020-11-10 09:00']
# Beyond LINE: 0.17333333333333334
# table count: 1416
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [0, 0, 67]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1900.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-11-10 19:00'] to ['2020-11-10 09:00']
# Beyond LINE: 0.23076923076923078
# table count: 1416
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [0, 0, 67]
# win: 0
# lose: 0
# No Trade
# Posesstion: 1900.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-11-10 19:00'] to ['2020-11-10 09:00']
# Beyond LINE: 0.10227272727272728
# table count: 1416
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 05:00']
# HIGH/LOW/STAY
# [5, 3, 59]
# win: 2
# lose: 6
# Rate: 0.25
# Posesstion: -2300.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-11-10 19:00'] to ['2020-11-10 09:00']
# Beyond LINE: 0.07692307692307693
# table count: 1416
#
# test data
# ['2020-12-22 11:00'] to ['2020-12-25 06:00']
# HIGH/LOW/STAY
# [0, 0, 68]
# win: 0
# lose: 0
# No Trade
# Posesstion: -2300.0
# RESULT: -2300.0
# Trade/Trade chance: 37/202115
# Trade rate: 0.00018306409717240186
# Rate: 0.35135135135135137
#
# TEST: 8
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-11-06 15:00'] to ['2020-11-06 05:00']
# Beyond LINE: 0.24193548387096775
# table count: 1416
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: -2300.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-11-06 15:00'] to ['2020-11-06 05:00']
# Beyond LINE: 0.2
# table count: 1416
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: -2300.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-11-06 15:00'] to ['2020-11-06 05:00']
# Beyond LINE: 0.2894736842105263
# table count: 1416
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [0, 0, 43]
# win: 0
# lose: 0
# No Trade
# Posesstion: -2300.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-11-06 15:00'] to ['2020-11-06 05:00']
# Beyond LINE: 0.14492753623188406
# table count: 1416
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [0, 1, 42]
# win: 1
# lose: 0
# Rate: 1.0
# Posesstion: -1400.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-11-06 15:00'] to ['2020-11-06 05:00']
# Beyond LINE: 0.10227272727272728
# table count: 1416
#
# test data
# ['2020-12-18 07:00'] to ['2020-12-22 01:00']
# HIGH/LOW/STAY
# [1, 0, 42]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: -2400.0
# RESULT: -2400.0
# Trade/Trade chance: 39/202330
# Trade rate: 0.00019275441111056197
# Rate: 0.358974358974359
#
# TEST: 9
# "AUD_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_JPY_2020-12-09_2021-01-20_1000.csv", "EUR_USD_2020-12-09_2021-01-20_1000.csv", "GBP_JPY_2020-12-09_2021-01-20_1000.csv", "USD_JPY_2020-12-09_2021-01-20_1000.csv",
# -----------------------
# AUD_JPY
# Table data
# ['2020-11-02 16:00'] to ['2020-10-31 04:00']
# Beyond LINE: 0.1262135922330097
# table count: 1427
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [0, 0, 78]
# win: 0
# lose: 0
# No Trade
# Posesstion: -2400.0
#
# -----------------------
# EUR_JPY
# Table data
# ['2020-11-02 16:00'] to ['2020-10-31 04:00']
# Beyond LINE: 0.15151515151515152
# table count: 1427
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [1, 0, 77]
# win: 0
# lose: 1
# Rate: 0.0
# Posesstion: -3400.0
#
# -----------------------
# EUR_USD
# Table data
# ['2020-11-02 16:00'] to ['2020-10-31 04:00']
# Beyond LINE: 0.16666666666666666
# table count: 1427
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [0, 0, 78]
# win: 0
# lose: 0
# No Trade
# Posesstion: -3400.0
#
# -----------------------
# GBP_JPY
# Table data
# ['2020-11-02 16:00'] to ['2020-10-31 04:00']
# Beyond LINE: 0.12056737588652482
# table count: 1427
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [2, 2, 74]
# win: 1
# lose: 3
# Rate: 0.25
# Posesstion: -5500.0
#
# -----------------------
# USD_JPY
# Table data
# ['2020-11-02 16:00'] to ['2020-10-31 04:00']
# Beyond LINE: 0.1056338028169014
# table count: 1427
#
# test data
# ['2020-12-14 16:00'] to ['2020-12-17 21:00']
# HIGH/LOW/STAY
# [2, 0, 76]
# win: 0
# lose: 2
# Rate: 0.0
# Posesstion: -7500.0
# RESULT: -7500.0
# Trade/Trade chance: 46/202720
# Trade rate: 0.00022691397000789267
# Rate: 0.32608695652173914

# %%
#DNUM: 300, range:10, 12/12~1/22
#not 0 falut
#0 reset 20500 rate:0.526...
#-1 antize 88200 rate:0.575...

#DNUM: 300, range:100, 2019/12/03~2021/1/22
#0 reset 396400 rate:0.526...
#-1 antize 971200 rate:0.590...


#DNUM: 300, range:100, 2019/12/03~2021/1/22 GRID=7
#-1 antize 409000 rate:0.5797...

#DNUM: 300, range:100, 2019/12/03~2021/1/22 GRID=6
#-1 antize 890400 rate:0.5936...

#DNUM: 300, range:100, 2019/12/03~2021/1/22 GRID=5
#-1 antize 2039900 rate:0.6183...

#DNUM: 300, range:100, 2019/12/03~2021/1/22 GRID=4
#-1 antize 3114100 rate:0.6091...

#DNUM: 300, range:100, 2019/12/03~2021/1/22 GRID=3
#-1 antize 11614400 rate:0.68851...

#DNUM: 100, range:100, 2019/12/03~2021/1/22 GRID=3
#-1 antize (2671400) rate:0.67243...

#DNUM: 200, range:100, 2019/12/03~2021/1/22 GRID=3
#-1 antize (3069000) rate:0.67419...

#DNUM: 400, range:100, 2019/12/03~2021/1/22 GRID=3
#-1 antize (2945100) rate:0.65800...

#DNUM: 300, range:1000, 2009/8/28~2021/1/22 GRID=3
#-1 antize (27751500) rate:0.65301...
