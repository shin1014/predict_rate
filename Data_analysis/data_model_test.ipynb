# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score

def show_data_relation(dataname):
    df = pd.read_csv(dataname, index_col='Datetime')
    df = df.astype('double')
    
    count = [0, 0, 0]
    df['class'] = (df["Rate"]).apply(lambda x: classify(x, count, 0.001))
    df['class'] = df['class'].shift(-1)
    print(' LOW/MID/HIGH')
    print(count)
    sns.pairplot(df, hue='class', palette='RdYlBu', height=8, kind='reg').savefig('./data_plot'+dataname+'.png')
    
#     iris = sns.load_dataset("iris")
#     sns.pairplot(iris, hue='species', palette='RdYlBu', height=8, kind='reg', diag_kind='kde')

    
def classify(x, c, R=0.01):
        if x<=-R:
            c[0]+=1
            return 0
        elif -R<x<R:
            c[1]+=1
            return 1
        elif R<=x:
            c[2]+=1
            return 2

def predict(dataname):

    df = pd.read_csv(dataname, index_col='Datetime')
    count = [0,0,0]
    df['class'] = (df["Rate"]).apply(lambda x: classify(x, count, 0.001))
    df['class'] = df['class'].shift(-1)
    print(" LOW/MID/HIGH")
    print(count)
    
    
    X = df.drop('class', axis=1)
    y = df['class']
    X = X.drop(X.index[len(X)-1])
    y = y.dropna()
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)
    
    names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
             "Random Forest", "AdaBoost", "Naive Bayes", "Linear Discriminant Analysis",
             "Quadratic Discriminant Analysis"]
    classifiers = [
        KNeighborsClassifier(3),
        SVC(kernel="linear", C=0.025),
        SVC(gamma=2, C=1),
        DecisionTreeClassifier(max_depth=5),
        RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
        AdaBoostClassifier(),
        GaussianNB(),
        LinearDiscriminantAnalysis(),
        QuadraticDiscriminantAnalysis()]
    
    for name, clf in zip(names, classifiers):
        print(name)
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        result = clf.predict(X_test)
        
        print(score)
        print('accuracy_score: ', end='')
        print(accuracy_score(y_test, result))
        print('confusion_matrix: ')
        print(confusion_matrix(y_test, result))
        print('precision_score: ', end='')
        print(precision_score(y_test, result, average=None))
        print('')

def main():
    namelist = ['20101to20208_USD_JPY_D.csv','20101to20208_EUR_JPY_D.csv','20101to20208_AUD_JPY_D.csv','20101to20208_GBP_JPY_D.csv','20101to20208_NZD_JPY_D.csv','20101to20208_CAD_JPY_D.csv','20101to20208_CHF_JPY_D.csv','20101to20208_ZAR_JPY_D.csv']
    
    for i in range(len(namelist)):
        print(namelist[i])
        predict(namelist[i]) 
        #show_data_relation(namelist[i])
    
 
main()
# Out:
# 20101to20208_USD_JPY_D.csv
#  LOW/MID/HIGH
# [815, 573, 801]
# Nearest Neighbors
# 0.4132420091324201
# accuracy_score: 0.4132420091324201
# confusion_matrix:
# [[101  26  42]
#  [ 62  25  31]
#  [ 71  25  55]]
# precision_score: [0.43162393 0.32894737 0.4296875 ]
#
# Linear SVM
# 0.3858447488584475
# accuracy_score: 0.3858447488584475
# confusion_matrix:
# [[141  17  11]
#  [ 89  16  13]
#  [130   9  12]]
# precision_score: [0.39166667 0.38095238 0.33333333]
#
# RBF SVM
# 0.3812785388127854
# accuracy_score: 0.3812785388127854
# confusion_matrix:
# [[158   2   9]
#  [104   6   8]
#  [142   6   3]]
# precision_score: [0.39108911 0.42857143 0.15      ]
#
# Decision Tree
# 0.3744292237442922
# accuracy_score: 0.3744292237442922
# confusion_matrix:
# [[79  7 83]
#  [47 11 60]
#  [71  6 74]]
# precision_score: [0.40101523 0.45833333 0.34101382]
#
# Random Forest
# 0.3835616438356164
# accuracy_score: 0.3835616438356164
# confusion_matrix:
# [[82 19 68]
#  [42 25 51]
#  [72 18 61]]
# precision_score: [0.41836735 0.40322581 0.33888889]
#
# AdaBoost
# 0.4155251141552511
# accuracy_score: 0.4155251141552511
# confusion_matrix:
# [[87 18 64]
#  [48 26 44]
#  [67 15 69]]
# precision_score: [0.43069307 0.44067797 0.38983051]
#
# Naive Bayes
# 0.3538812785388128
# accuracy_score: 0.3538812785388128
# confusion_matrix:
# [[88 57 24]
#  [56 49 13]
#  [93 40 18]]
# precision_score: [0.37130802 0.33561644 0.32727273]
#
# Linear Discriminant Analysis
# 0.3561643835616438
# accuracy_score: 0.3561643835616438
# confusion_matrix:
# [[71 26 72]
#  [50 32 36]
#  [79 19 53]]
# precision_score: [0.355      0.41558442 0.32919255]
#
# Quadratic Discriminant Analysis
# 0.3538812785388128
# accuracy_score: 0.3538812785388128
# confusion_matrix:
# [[94 48 27]
#  [53 49 16]
#  [95 44 12]]
# precision_score: [0.38842975 0.34751773 0.21818182]
#
# 20101to20208_EUR_JPY_D.csv
#  LOW/MID/HIGH
# [866, 456, 859]
# Nearest Neighbors
# 0.38073394495412843
# accuracy_score: 0.38073394495412843
# confusion_matrix:
# [[88 24 68]
#  [50 14 28]
#  [82 18 64]]
# precision_score: [0.4  0.25 0.4 ]
#
# Linear SVM
# 0.42201834862385323
# accuracy_score: 0.42201834862385323
# confusion_matrix:
# [[118  17  45]
#  [ 55  11  26]
#  [ 98  11  55]]
# precision_score: [0.43542435 0.28205128 0.43650794]
#
# RBF SVM
# 0.3876146788990826
# accuracy_score: 0.3876146788990826
# confusion_matrix:
# [[  9   3 168]
#  [  4   1  87]
#  [  2   3 159]]
# precision_score: [0.6        0.14285714 0.38405797]
#
# Decision Tree
# 0.3463302752293578
# accuracy_score: 0.3463302752293578
# confusion_matrix:
# [[115   3  62]
#  [ 70   0  22]
#  [121   7  36]]
# precision_score: [0.37581699 0.         0.3       ]
#
# Random Forest
# 0.36009174311926606
# accuracy_score: 0.36009174311926606
# confusion_matrix:
# [[80  2 98]
#  [56  3 33]
#  [86  4 74]]
# precision_score: [0.36036036 0.33333333 0.36097561]
#
# AdaBoost
# 0.3967889908256881
# accuracy_score: 0.3967889908256881
# confusion_matrix:
# [[99  8 73]
#  [54  3 35]
#  [91  2 71]]
# precision_score: [0.4057377  0.23076923 0.39664804]
#
# Naive Bayes
# 0.41743119266055045
# accuracy_score: 0.41743119266055045
# confusion_matrix:
# [[124   0  56]
#  [ 59   0  33]
#  [106   0  58]]
# precision_score: [0.42906574 0.         0.39455782]
#
# Linear Discriminant Analysis
# 0.4197247706422018
# accuracy_score: 0.4197247706422018
# confusion_matrix:
# [[106   0  74]
#  [ 56   0  36]
#  [ 87   0  77]]
# precision_score: [0.42570281 0.         0.41176471]
#
# Quadratic Discriminant Analysis
# 0.39908256880733944
# accuracy_score: 0.39908256880733944
# confusion_matrix:
# [[146   5  29]
#  [ 84   1   7]
#  [134   3  27]]
# precision_score: [0.4010989  0.11111111 0.42857143]
#
# 20101to20208_AUD_JPY_D.csv
#  LOW/MID/HIGH
# [867, 406, 906]
# Nearest Neighbors
# 0.3830275229357798
# accuracy_score: 0.3830275229357798
# confusion_matrix:
# [[ 82  22  63]
#  [ 40  12  26]
#  [105  13  73]]
# precision_score: [0.36123348 0.25531915 0.45061728]
#
# Linear SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.3623853211009174
# accuracy_score: 0.3623853211009174
# confusion_matrix:
# [[149  15   3]
#  [ 71   6   1]
#  [177  11   3]]
# precision_score: [0.37531486 0.1875     0.42857143]
#
# RBF SVM
# 0.4334862385321101
# accuracy_score: 0.4334862385321101
# confusion_matrix:
# [[  2   3 162]
#  [  3   4  71]
#  [  2   6 183]]
# precision_score: [0.28571429 0.30769231 0.43990385]
#
# Decision Tree
# 0.4105504587155963
# accuracy_score: 0.4105504587155963
# confusion_matrix:
# [[ 18   3 146]
#  [  7   2  69]
#  [ 28   4 159]]
# precision_score: [0.33962264 0.22222222 0.42513369]
#
# Random Forest
# 0.3922018348623853
# accuracy_score: 0.3922018348623853
# confusion_matrix:
# [[ 67   0 100]
#  [ 37   0  41]
#  [ 87   0 104]]
# precision_score: [0.35078534 0.         0.4244898 ]
#
# AdaBoost
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.41284403669724773
# accuracy_score: 0.41284403669724773
# confusion_matrix:
# [[83  2 82]
#  [29  0 49]
#  [94  0 97]]
# precision_score: [0.40291262 0.         0.4254386 ]
#
# Naive Bayes
# 0.4197247706422018
# accuracy_score: 0.4197247706422018
# confusion_matrix:
# [[ 96   0  71]
#  [ 50   0  28]
#  [104   0  87]]
# precision_score: [0.384      0.         0.46774194]
#
# Linear Discriminant Analysis
# 0.4013761467889908
# accuracy_score: 0.4013761467889908
# confusion_matrix:
# [[ 64   0 103]
#  [ 30   0  48]
#  [ 80   0 111]]
# precision_score: [0.36781609 0.         0.42366412]
#
# Quadratic Discriminant Analysis
# 0.33256880733944955
# accuracy_score: 0.33256880733944955
# confusion_matrix:
# [[78 62 27]
#  [32 33 13]
#  [83 74 34]]
# precision_score: [0.40414508 0.19526627 0.45945946]
#
# 20101to20208_GBP_JPY_D.csv
#  LOW/MID/HIGH
# [841, 441, 899]
# Nearest Neighbors
# 0.4059633027522936
# accuracy_score: 0.4059633027522936
# confusion_matrix:
# [[80 27 49]
#  [52 22 32]
#  [86 13 75]]
# precision_score: [0.36697248 0.35483871 0.48076923]
#
# Linear SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.42660550458715596
# accuracy_score: 0.42660550458715596
# confusion_matrix:
# [[  5   9 142]
#  [  2  19  85]
#  [  1  11 162]]
# precision_score: [0.625      0.48717949 0.41645244]
#
# RBF SVM
# 0.39908256880733944
# accuracy_score: 0.39908256880733944
# confusion_matrix:
# [[  3   0 153]
#  [  7   3  96]
#  [  4   2 168]]
# precision_score: [0.21428571 0.6        0.4028777 ]
#
# Decision Tree
# 0.41743119266055045
# accuracy_score: 0.41743119266055045
# confusion_matrix:
# [[ 53   3 100]
#  [ 29   9  68]
#  [ 49   5 120]]
# precision_score: [0.40458015 0.52941176 0.41666667]
#
# Random Forest
# 0.37844036697247707
# accuracy_score: 0.37844036697247707
# confusion_matrix:
# [[ 47   4 105]
#  [ 37  13  56]
#  [ 65   4 105]]
# precision_score: [0.31543624 0.61904762 0.39473684]
#
# AdaBoost
# 0.3876146788990826
# accuracy_score: 0.3876146788990826
# confusion_matrix:
# [[74  4 78]
#  [49  9 48]
#  [83  5 86]]
# precision_score: [0.3592233  0.5        0.40566038]
#
# Naive Bayes
# 0.3394495412844037
# accuracy_score: 0.3394495412844037
# confusion_matrix:
# [[63 10 83]
#  [44  6 56]
#  [89  6 79]]
# precision_score: [0.32142857 0.27272727 0.36238532]
#
# Linear Discriminant Analysis
# 0.4036697247706422
# accuracy_score: 0.4036697247706422
# confusion_matrix:
# [[ 54   0 102]
#  [ 34   0  72]
#  [ 52   0 122]]
# precision_score: [0.38571429 0.         0.41216216]
#
# Quadratic Discriminant Analysis
# 0.3830275229357798
# accuracy_score: 0.3830275229357798
# confusion_matrix:
# [[18 61 77]
#  [ 9 57 40]
#  [17 65 92]]
# precision_score: [0.40909091 0.31147541 0.44019139]
#
# 20101to20208_NZD_JPY_D.csv
#  LOW/MID/HIGH
# [894, 395, 900]
# Nearest Neighbors
# 0.4246575342465753
# accuracy_score: 0.4246575342465753
# confusion_matrix:
# [[107  15  51]
#  [ 32  10  26]
#  [107  21  69]]
# precision_score: [0.43495935 0.2173913  0.47260274]
#
# Linear SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.3904109589041096
# accuracy_score: 0.3904109589041096
# confusion_matrix:
# [[159  11   3]
#  [ 61   7   0]
#  [180  12   5]]
# precision_score: [0.3975     0.23333333 0.625     ]
#
# RBF SVM
# 0.3972602739726027
# accuracy_score: 0.3972602739726027
# confusion_matrix:
# [[164   4   5]
#  [ 66   1   1]
#  [187   1   9]]
# precision_score: [0.39328537 0.16666667 0.6       ]
#
# Decision Tree
# 0.4246575342465753
# accuracy_score: 0.4246575342465753
# confusion_matrix:
# [[ 81   1  91]
#  [ 25   0  43]
#  [ 91   1 105]]
# precision_score: [0.41116751 0.         0.43933054]
#
# Random Forest
# 0.4520547945205479
# accuracy_score: 0.4520547945205479
# confusion_matrix:
# [[117   0  56]
#  [ 50   1  17]
#  [117   0  80]]
# precision_score: [0.41197183 1.         0.52287582]
#
# AdaBoost
# 0.4132420091324201
# accuracy_score: 0.4132420091324201
# confusion_matrix:
# [[86  9 78]
#  [35  1 32]
#  [98  5 94]]
# precision_score: [0.39269406 0.06666667 0.46078431]
#
# Naive Bayes
# 0.3447488584474886
# accuracy_score: 0.3447488584474886
# confusion_matrix:
# [[ 98  38  37]
#  [ 35  12  21]
#  [107  49  41]]
# precision_score: [0.40833333 0.12121212 0.41414141]
#
# Linear Discriminant Analysis
# 0.4292237442922374
# accuracy_score: 0.4292237442922374
# confusion_matrix:
# [[ 99   0  74]
#  [ 35   0  33]
#  [108   0  89]]
# precision_score: [0.40909091 0.         0.45408163]
#
# Quadratic Discriminant Analysis
# 0.3470319634703196
# accuracy_score: 0.3470319634703196
# confusion_matrix:
# [[118  31  24]
#  [ 43  18   7]
#  [135  46  16]]
# precision_score: [0.39864865 0.18947368 0.34042553]
#
# 20101to20208_CAD_JPY_D.csv
#  LOW/MID/HIGH
# [882, 405, 893]
# Nearest Neighbors
# 0.39908256880733944
# accuracy_score: 0.39908256880733944
# confusion_matrix:
# [[96 12 56]
#  [52  7 32]
#  [93 17 71]]
# precision_score: [0.39834025 0.19444444 0.44654088]
#
# Linear SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.35091743119266056
# accuracy_score: 0.35091743119266056
# confusion_matrix:
# [[143  12   9]
#  [ 80   8   3]
#  [164  15   2]]
# precision_score: [0.36950904 0.22857143 0.14285714]
#
# RBF SVM
# 0.3555045871559633
# accuracy_score: 0.3555045871559633
# confusion_matrix:
# [[148   5  11]
#  [ 82   1   8]
#  [172   3   6]]
# precision_score: [0.3681592  0.11111111 0.24      ]
#
# Decision Tree
# 0.40825688073394495
# accuracy_score: 0.40825688073394495
# confusion_matrix:
# [[114   8  42]
#  [ 73   4  14]
#  [111  10  60]]
# precision_score: [0.38255034 0.18181818 0.51724138]
#
# Random Forest
# 0.41284403669724773
# accuracy_score: 0.41284403669724773
# confusion_matrix:
# [[101   0  63]
#  [ 55   1  35]
#  [102   1  78]]
# precision_score: [0.39147287 0.5        0.44318182]
#
# AdaBoost
# 0.40825688073394495
# accuracy_score: 0.40825688073394495
# confusion_matrix:
# [[91  8 65]
#  [50  6 35]
#  [89 11 81]]
# precision_score: [0.39565217 0.24       0.44751381]
#
# Naive Bayes
# 0.4013761467889908
# accuracy_score: 0.4013761467889908
# confusion_matrix:
# [[ 63   0 101]
#  [ 40   0  51]
#  [ 69   0 112]]
# precision_score: [0.36627907 0.         0.42424242]
#
# Linear Discriminant Analysis
# 0.3944954128440367
# accuracy_score: 0.3944954128440367
# confusion_matrix:
# [[88  0 76]
#  [52  0 39]
#  [97  0 84]]
# precision_score: [0.37130802 0.         0.42211055]
#
# Quadratic Discriminant Analysis
# 0.3876146788990826
# accuracy_score: 0.3876146788990826
# confusion_matrix:
# [[126   4  34]
#  [ 70   3  18]
#  [139   2  40]]
# precision_score: [0.3761194  0.33333333 0.43478261]
#
# 20101to20208_CHF_JPY_D.csv
#  LOW/MID/HIGH
# [838, 477, 866]
# Nearest Neighbors
# 0.3440366972477064
# accuracy_score: 0.3440366972477064
# confusion_matrix:
# [[ 87  17  63]
#  [ 53   8  33]
#  [101  19  55]]
# precision_score: [0.36099585 0.18181818 0.36423841]
#
# Linear SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.3853211009174312
# accuracy_score: 0.3853211009174312
# confusion_matrix:
# [[  8   6 153]
#  [  8   8  78]
#  [  8  15 152]]
# precision_score: [0.33333333 0.27586207 0.39686684]
#
# RBF SVM
# 0.3967889908256881
# accuracy_score: 0.3967889908256881
# confusion_matrix:
# [[  2   3 162]
#  [  1   1  92]
#  [  5   0 170]]
# precision_score: [0.25      0.25      0.4009434]
#
# Decision Tree
# 0.3669724770642202
# accuracy_score: 0.3669724770642202
# confusion_matrix:
# [[  6   9 152]
#  [  3   6  85]
#  [ 14  13 148]]
# precision_score: [0.26086957 0.21428571 0.38441558]
#
# Random Forest
# 0.38990825688073394
# accuracy_score: 0.38990825688073394
# confusion_matrix:
# [[ 56   4 107]
#  [ 36   3  55]
#  [ 59   5 111]]
# precision_score: [0.37086093 0.25       0.40659341]
#
# AdaBoost
# 0.3669724770642202
# accuracy_score: 0.3669724770642202
# confusion_matrix:
# [[69  4 94]
#  [47  6 41]
#  [76 14 85]]
# precision_score: [0.359375   0.25       0.38636364]
#
# Naive Bayes
# 0.3853211009174312
# accuracy_score: 0.3853211009174312
# confusion_matrix:
# [[79 46 42]
#  [37 34 23]
#  [74 46 55]]
# precision_score: [0.41578947 0.26984127 0.45833333]
#
# Linear Discriminant Analysis
# 0.37155963302752293
# accuracy_score: 0.37155963302752293
# confusion_matrix:
# [[ 60   0 107]
#  [ 30   0  64]
#  [ 73   0 102]]
# precision_score: [0.36809816 0.         0.37362637]
#
# Quadratic Discriminant Analysis
# 0.3165137614678899
# accuracy_score: 0.3165137614678899
# confusion_matrix:
# [[11 96 60]
#  [ 2 67 25]
#  [20 95 60]]
# precision_score: [0.33333333 0.25968992 0.4137931 ]
#
# 20101to20208_ZAR_JPY_D.csv
#  LOW/MID/HIGH
# [934, 311, 930]
# Nearest Neighbors
# 0.38620689655172413
# accuracy_score: 0.38620689655172413
# confusion_matrix:
# [[92 11 91]
#  [30  6 24]
#  [95 16 70]]
# precision_score: [0.42396313 0.18181818 0.37837838]
#
# Linear SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4068965517241379
# accuracy_score: 0.4068965517241379
# confusion_matrix:
# [[ 76   0 118]
#  [ 19   0  41]
#  [ 80   0 101]]
# precision_score: [0.43428571 0.         0.38846154]
#
# RBF SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.42758620689655175
# accuracy_score: 0.42758620689655175
# confusion_matrix:
# [[ 17   5 172]
#  [  4   2  54]
#  [  8   6 167]]
# precision_score: [0.5862069  0.15384615 0.42493639]
#
# Decision Tree
# 0.4160919540229885
# accuracy_score: 0.4160919540229885
# confusion_matrix:
# [[ 32   1 161]
#  [ 17   2  41]
#  [ 29   5 147]]
# precision_score: [0.41025641 0.25       0.42120344]
#
# Random Forest
# 0.4045977011494253
# accuracy_score: 0.4045977011494253
# confusion_matrix:
# [[ 75   2 117]
#  [ 34   1  25]
#  [ 78   3 100]]
# precision_score: [0.40106952 0.16666667 0.41322314]
#
# AdaBoost
# 0.41379310344827586
# accuracy_score: 0.41379310344827586
# confusion_matrix:
# [[95  4 95]
#  [27  3 30]
#  [95  4 82]]
# precision_score: [0.43778802 0.27272727 0.39613527]
#
# Naive Bayes
# 0.35172413793103446
# accuracy_score: 0.35172413793103446
# confusion_matrix:
# [[ 33  37 124]
#  [ 18  19  23]
#  [ 40  40 101]]
# precision_score: [0.36263736 0.19791667 0.40725806]
#
# Linear Discriminant Analysis
# 0.3931034482758621
# accuracy_score: 0.3931034482758621
# confusion_matrix:
# [[ 83   0 111]
#  [ 32   0  28]
#  [ 93   0  88]]
# precision_score: [0.39903846 0.         0.3876652 ]
#
# Quadratic Discriminant Analysis
# 0.3816091954022989
# accuracy_score: 0.3816091954022989
# confusion_matrix:
# [[ 54  23 117]
#  [ 16  14  30]
#  [ 56  27  98]]
# precision_score: [0.42857143 0.21875    0.4       ]
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
20101to20208_USD_JPY_D.csv
 LOW/MID/HIGH
[815, 573, 801]
Nearest Neighbors
0.4132420091324201
accuracy_score: 0.4132420091324201
confusion_matrix: 
[[101  26  42]
 [ 62  25  31]
 [ 71  25  55]]
precision_score: [0.43162393 0.32894737 0.4296875 ]

Linear SVM
0.3858447488584475
accuracy_score: 0.3858447488584475
confusion_matrix: 
[[141  17  11]
 [ 89  16  13]
 [130   9  12]]
precision_score: [0.39166667 0.38095238 0.33333333]

RBF SVM
0.3812785388127854
accuracy_score: 0.3812785388127854
confusion_matrix: 
[[158   2   9]
 [104   6   8]
 [142   6   3]]
precision_score: [0.39108911 0.42857143 0.15      ]

Decision Tree
0.3744292237442922
accuracy_score: 0.3744292237442922
confusion_matrix: 
[[79  7 83]
 [47 11 60]
 [71  6 74]]
precision_score: [0.40101523 0.45833333 0.34101382]

Random Forest
0.3835616438356164
accuracy_score: 0.3835616438356164
confusion_matrix: 
[[82 19 68]
 [42 25 51]
 [72 18 61]]
precision_score: [0.41836735 0.40322581 0.33888889]

AdaBoost
0.4155251141552511
accuracy_score: 0.4155251141552511
confusion_matrix: 
[[87 18 64]
 [48 26 44]
 [67 15 69]]
precision_score: [0.43069307 0.44067797 0.38983051]

Naive Bayes
0.3538812785388128
accuracy_score: 0.3538812785388128
confusion_matrix: 
[[88 57 24]
 [56 49 13]
 [93 40 18]]
precision_score: [0.37130802 0.33561644 0.32727273]

Linear Discriminant Analysis
0.3561643835616438
accuracy_score: 0.3561643835616438
confusion_matrix: 
[[71 26 72]
 [50 32 36]
 [79 19 53]]
precision_score: [0.355      0.41558442 0.32919255]

Quadratic Discriminant Analysis
0.3538812785388128
accuracy_score: 0.3538812785388128
confusion_matrix: 
[[94 48 27]
 [53 49 16]
 [95 44 12]]
precision_score: [0.38842975 0.34751773 0.21818182]

20101to20208_EUR_JPY_D.csv
 LOW/MID/HIGH
[866, 456, 859]
Nearest Neighbors
0.38073394495412843
accuracy_score: 0.38073394495412843
confusion_matrix: 
[[88 24 68]
 [50 14 28]
 [82 18 64]]
precision_score: [0.4  0.25 0.4 ]

Linear SVM
0.42201834862385323
accuracy_score: 0.42201834862385323
confusion_matrix: 
[[118  17  45]
 [ 55  11  26]
 [ 98  11  55]]
precision_score: [0.43542435 0.28205128 0.43650794]

RBF SVM
0.3876146788990826
accuracy_score: 0.3876146788990826
confusion_matrix: 
[[  9   3 168]
 [  4   1  87]
 [  2   3 159]]
precision_score: [0.6        0.14285714 0.38405797]

Decision Tree
0.3463302752293578
accuracy_score: 0.3463302752293578
confusion_matrix: 
[[115   3  62]
 [ 70   0  22]
 [121   7  36]]
precision_score: [0.37581699 0.         0.3       ]

Random Forest
0.36009174311926606
accuracy_score: 0.36009174311926606
confusion_matrix: 
[[80  2 98]
 [56  3 33]
 [86  4 74]]
precision_score: [0.36036036 0.33333333 0.36097561]

AdaBoost
0.3967889908256881
accuracy_score: 0.3967889908256881
confusion_matrix: 
[[99  8 73]
 [54  3 35]
 [91  2 71]]
precision_score: [0.4057377  0.23076923 0.39664804]

Naive Bayes
0.41743119266055045
accuracy_score: 0.41743119266055045
confusion_matrix: 
[[124   0  56]
 [ 59   0  33]
 [106   0  58]]
precision_score: [0.42906574 0.         0.39455782]

Linear Discriminant Analysis
0.4197247706422018
accuracy_score: 0.4197247706422018
confusion_matrix: 
[[106   0  74]
 [ 56   0  36]
 [ 87   0  77]]
precision_score: [0.42570281 0.         0.41176471]

Quadratic Discriminant Analysis
0.39908256880733944
accuracy_score: 0.39908256880733944
confusion_matrix: 
[[146   5  29]
 [ 84   1   7]
 [134   3  27]]
precision_score: [0.4010989  0.11111111 0.42857143]

20101to20208_AUD_JPY_D.csv
 LOW/MID/HIGH
[867, 406, 906]
Nearest Neighbors
0.3830275229357798
accuracy_score: 0.3830275229357798
confusion_matrix: 
[[ 82  22  63]
 [ 40  12  26]
 [105  13  73]]
precision_score: [0.36123348 0.25531915 0.45061728]

Linear SVM
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.3623853211009174
accuracy_score: 0.3623853211009174
confusion_matrix: 
[[149  15   3]
 [ 71   6   1]
 [177  11   3]]
precision_score: [0.37531486 0.1875     0.42857143]

RBF SVM
0.4334862385321101
accuracy_score: 0.4334862385321101
confusion_matrix: 
[[  2   3 162]
 [  3   4  71]
 [  2   6 183]]
precision_score: [0.28571429 0.30769231 0.43990385]

Decision Tree
0.4105504587155963
accuracy_score: 0.4105504587155963
confusion_matrix: 
[[ 18   3 146]
 [  7   2  69]
 [ 28   4 159]]
precision_score: [0.33962264 0.22222222 0.42513369]

Random Forest
0.3922018348623853
accuracy_score: 0.3922018348623853
confusion_matrix: 
[[ 67   0 100]
 [ 37   0  41]
 [ 87   0 104]]
precision_score: [0.35078534 0.         0.4244898 ]

AdaBoost
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.41284403669724773
accuracy_score: 0.41284403669724773
confusion_matrix: 
[[83  2 82]
 [29  0 49]
 [94  0 97]]
precision_score: [0.40291262 0.         0.4254386 ]

Naive Bayes
0.4197247706422018
accuracy_score: 0.4197247706422018
confusion_matrix: 
[[ 96   0  71]
 [ 50   0  28]
 [104   0  87]]
precision_score: [0.384      0.         0.46774194]

Linear Discriminant Analysis
0.4013761467889908
accuracy_score: 0.4013761467889908
confusion_matrix: 
[[ 64   0 103]
 [ 30   0  48]
 [ 80   0 111]]
precision_score: [0.36781609 0.         0.42366412]

Quadratic Discriminant Analysis
0.33256880733944955
accuracy_score: 0.33256880733944955
confusion_matrix: 
[[78 62 27]
 [32 33 13]
 [83 74 34]]
precision_score: [0.40414508 0.19526627 0.45945946]

20101to20208_GBP_JPY_D.csv
 LOW/MID/HIGH
[841, 441, 899]
Nearest Neighbors
0.4059633027522936
accuracy_score: 0.4059633027522936
confusion_matrix: 
[[80 27 49]
 [52 22 32]
 [86 13 75]]
precision_score: [0.36697248 0.35483871 0.48076923]

Linear SVM
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.42660550458715596
accuracy_score: 0.42660550458715596
confusion_matrix: 
[[  5   9 142]
 [  2  19  85]
 [  1  11 162]]
precision_score: [0.625      0.48717949 0.41645244]

RBF SVM
0.39908256880733944
accuracy_score: 0.39908256880733944
confusion_matrix: 
[[  3   0 153]
 [  7   3  96]
 [  4   2 168]]
precision_score: [0.21428571 0.6        0.4028777 ]

Decision Tree
0.41743119266055045
accuracy_score: 0.41743119266055045
confusion_matrix: 
[[ 53   3 100]
 [ 29   9  68]
 [ 49   5 120]]
precision_score: [0.40458015 0.52941176 0.41666667]

Random Forest
0.37844036697247707
accuracy_score: 0.37844036697247707
confusion_matrix: 
[[ 47   4 105]
 [ 37  13  56]
 [ 65   4 105]]
precision_score: [0.31543624 0.61904762 0.39473684]

AdaBoost
0.3876146788990826
accuracy_score: 0.3876146788990826
confusion_matrix: 
[[74  4 78]
 [49  9 48]
 [83  5 86]]
precision_score: [0.3592233  0.5        0.40566038]

Naive Bayes
0.3394495412844037
accuracy_score: 0.3394495412844037
confusion_matrix: 
[[63 10 83]
 [44  6 56]
 [89  6 79]]
precision_score: [0.32142857 0.27272727 0.36238532]

Linear Discriminant Analysis
0.4036697247706422
accuracy_score: 0.4036697247706422
confusion_matrix: 
[[ 54   0 102]
 [ 34   0  72]
 [ 52   0 122]]
precision_score: [0.38571429 0.         0.41216216]

Quadratic Discriminant Analysis
0.3830275229357798
accuracy_score: 0.3830275229357798
confusion_matrix: 
[[18 61 77]
 [ 9 57 40]
 [17 65 92]]
precision_score: [0.40909091 0.31147541 0.44019139]

20101to20208_NZD_JPY_D.csv
 LOW/MID/HIGH
[894, 395, 900]
Nearest Neighbors
0.4246575342465753
accuracy_score: 0.4246575342465753
confusion_matrix: 
[[107  15  51]
 [ 32  10  26]
 [107  21  69]]
precision_score: [0.43495935 0.2173913  0.47260274]

Linear SVM
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.3904109589041096
accuracy_score: 0.3904109589041096
confusion_matrix: 
[[159  11   3]
 [ 61   7   0]
 [180  12   5]]
precision_score: [0.3975     0.23333333 0.625     ]

RBF SVM
0.3972602739726027
accuracy_score: 0.3972602739726027
confusion_matrix: 
[[164   4   5]
 [ 66   1   1]
 [187   1   9]]
precision_score: [0.39328537 0.16666667 0.6       ]

Decision Tree
0.4246575342465753
accuracy_score: 0.4246575342465753
confusion_matrix: 
[[ 81   1  91]
 [ 25   0  43]
 [ 91   1 105]]
precision_score: [0.41116751 0.         0.43933054]

Random Forest
0.4520547945205479
accuracy_score: 0.4520547945205479
confusion_matrix: 
[[117   0  56]
 [ 50   1  17]
 [117   0  80]]
precision_score: [0.41197183 1.         0.52287582]

AdaBoost
0.4132420091324201
accuracy_score: 0.4132420091324201
confusion_matrix: 
[[86  9 78]
 [35  1 32]
 [98  5 94]]
precision_score: [0.39269406 0.06666667 0.46078431]

Naive Bayes
0.3447488584474886
accuracy_score: 0.3447488584474886
confusion_matrix: 
[[ 98  38  37]
 [ 35  12  21]
 [107  49  41]]
precision_score: [0.40833333 0.12121212 0.41414141]

Linear Discriminant Analysis
0.4292237442922374
accuracy_score: 0.4292237442922374
confusion_matrix: 
[[ 99   0  74]
 [ 35   0  33]
 [108   0  89]]
precision_score: [0.40909091 0.         0.45408163]

Quadratic Discriminant Analysis
0.3470319634703196
accuracy_score: 0.3470319634703196
confusion_matrix: 
[[118  31  24]
 [ 43  18   7]
 [135  46  16]]
precision_score: [0.39864865 0.18947368 0.34042553]

20101to20208_CAD_JPY_D.csv
 LOW/MID/HIGH
[882, 405, 893]
Nearest Neighbors
0.39908256880733944
accuracy_score: 0.39908256880733944
confusion_matrix: 
[[96 12 56]
 [52  7 32]
 [93 17 71]]
precision_score: [0.39834025 0.19444444 0.44654088]

Linear SVM
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.35091743119266056
accuracy_score: 0.35091743119266056
confusion_matrix: 
[[143  12   9]
 [ 80   8   3]
 [164  15   2]]
precision_score: [0.36950904 0.22857143 0.14285714]

RBF SVM
0.3555045871559633
accuracy_score: 0.3555045871559633
confusion_matrix: 
[[148   5  11]
 [ 82   1   8]
 [172   3   6]]
precision_score: [0.3681592  0.11111111 0.24      ]

Decision Tree
0.40825688073394495
accuracy_score: 0.40825688073394495
confusion_matrix: 
[[114   8  42]
 [ 73   4  14]
 [111  10  60]]
precision_score: [0.38255034 0.18181818 0.51724138]

Random Forest
0.41284403669724773
accuracy_score: 0.41284403669724773
confusion_matrix: 
[[101   0  63]
 [ 55   1  35]
 [102   1  78]]
precision_score: [0.39147287 0.5        0.44318182]

AdaBoost
0.40825688073394495
accuracy_score: 0.40825688073394495
confusion_matrix: 
[[91  8 65]
 [50  6 35]
 [89 11 81]]
precision_score: [0.39565217 0.24       0.44751381]

Naive Bayes
0.4013761467889908
accuracy_score: 0.4013761467889908
confusion_matrix: 
[[ 63   0 101]
 [ 40   0  51]
 [ 69   0 112]]
precision_score: [0.36627907 0.         0.42424242]

Linear Discriminant Analysis
0.3944954128440367
accuracy_score: 0.3944954128440367
confusion_matrix: 
[[88  0 76]
 [52  0 39]
 [97  0 84]]
precision_score: [0.37130802 0.         0.42211055]

Quadratic Discriminant Analysis
0.3876146788990826
accuracy_score: 0.3876146788990826
confusion_matrix: 
[[126   4  34]
 [ 70   3  18]
 [139   2  40]]
precision_score: [0.3761194  0.33333333 0.43478261]

20101to20208_CHF_JPY_D.csv
 LOW/MID/HIGH
[838, 477, 866]
Nearest Neighbors
0.3440366972477064
accuracy_score: 0.3440366972477064
confusion_matrix: 
[[ 87  17  63]
 [ 53   8  33]
 [101  19  55]]
precision_score: [0.36099585 0.18181818 0.36423841]

Linear SVM
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.3853211009174312
accuracy_score: 0.3853211009174312
confusion_matrix: 
[[  8   6 153]
 [  8   8  78]
 [  8  15 152]]
precision_score: [0.33333333 0.27586207 0.39686684]

RBF SVM
0.3967889908256881
accuracy_score: 0.3967889908256881
confusion_matrix: 
[[  2   3 162]
 [  1   1  92]
 [  5   0 170]]
precision_score: [0.25      0.25      0.4009434]

Decision Tree
0.3669724770642202
accuracy_score: 0.3669724770642202
confusion_matrix: 
[[  6   9 152]
 [  3   6  85]
 [ 14  13 148]]
precision_score: [0.26086957 0.21428571 0.38441558]

Random Forest
0.38990825688073394
accuracy_score: 0.38990825688073394
confusion_matrix: 
[[ 56   4 107]
 [ 36   3  55]
 [ 59   5 111]]
precision_score: [0.37086093 0.25       0.40659341]

AdaBoost
0.3669724770642202
accuracy_score: 0.3669724770642202
confusion_matrix: 
[[69  4 94]
 [47  6 41]
 [76 14 85]]
precision_score: [0.359375   0.25       0.38636364]

Naive Bayes
0.3853211009174312
accuracy_score: 0.3853211009174312
confusion_matrix: 
[[79 46 42]
 [37 34 23]
 [74 46 55]]
precision_score: [0.41578947 0.26984127 0.45833333]

Linear Discriminant Analysis
0.37155963302752293
accuracy_score: 0.37155963302752293
confusion_matrix: 
[[ 60   0 107]
 [ 30   0  64]
 [ 73   0 102]]
precision_score: [0.36809816 0.         0.37362637]

Quadratic Discriminant Analysis
0.3165137614678899
accuracy_score: 0.3165137614678899
confusion_matrix: 
[[11 96 60]
 [ 2 67 25]
 [20 95 60]]
precision_score: [0.33333333 0.25968992 0.4137931 ]

20101to20208_ZAR_JPY_D.csv
 LOW/MID/HIGH
[934, 311, 930]
Nearest Neighbors
0.38620689655172413
accuracy_score: 0.38620689655172413
confusion_matrix: 
[[92 11 91]
 [30  6 24]
 [95 16 70]]
precision_score: [0.42396313 0.18181818 0.37837838]

Linear SVM
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.4068965517241379
accuracy_score: 0.4068965517241379
confusion_matrix: 
[[ 76   0 118]
 [ 19   0  41]
 [ 80   0 101]]
precision_score: [0.43428571 0.         0.38846154]

RBF SVM
C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
0.42758620689655175
accuracy_score: 0.42758620689655175
confusion_matrix: 
[[ 17   5 172]
 [  4   2  54]
 [  8   6 167]]
precision_score: [0.5862069  0.15384615 0.42493639]

Decision Tree
0.4160919540229885
accuracy_score: 0.4160919540229885
confusion_matrix: 
[[ 32   1 161]
 [ 17   2  41]
 [ 29   5 147]]
precision_score: [0.41025641 0.25       0.42120344]

Random Forest
0.4045977011494253
accuracy_score: 0.4045977011494253
confusion_matrix: 
[[ 75   2 117]
 [ 34   1  25]
 [ 78   3 100]]
precision_score: [0.40106952 0.16666667 0.41322314]

AdaBoost
0.41379310344827586
accuracy_score: 0.41379310344827586
confusion_matrix: 
[[95  4 95]
 [27  3 30]
 [95  4 82]]
precision_score: [0.43778802 0.27272727 0.39613527]

Naive Bayes
0.35172413793103446
accuracy_score: 0.35172413793103446
confusion_matrix: 
[[ 33  37 124]
 [ 18  19  23]
 [ 40  40 101]]
precision_score: [0.36263736 0.19791667 0.40725806]

Linear Discriminant Analysis
0.3931034482758621
accuracy_score: 0.3931034482758621
confusion_matrix: 
[[ 83   0 111]
 [ 32   0  28]
 [ 93   0  88]]
precision_score: [0.39903846 0.         0.3876652 ]

Quadratic Discriminant Analysis
0.3816091954022989
accuracy_score: 0.3816091954022989
confusion_matrix: 
[[ 54  23 117]
 [ 16  14  30]
 [ 56  27  98]]
precision_score: [0.42857143 0.21875    0.4       ]

C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
  _warn_prf(average, modifier, msg_start, len(result))
# Out:
#   File "<ipython-input-4-30ef71d49726>", line 1
#     20101to20208_USD_JPY_D.csv
#          ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score

def show_data_relation(dataname):
    df = pd.read_csv(dataname, index_col='Datetime')
    df = df.astype('double')
    
    count = [0, 0, 0]
    df['class'] = (df["Rate"]).apply(lambda x: classify(x, count, 0.001))
    df['class'] = df['class'].shift(-1)
    print(' LOW/MID/HIGH')
    print(count)
    sns.pairplot(df, hue='class', palette='RdYlBu', height=8, kind='reg').savefig('./data_plot'+dataname+'.png')
    
#     iris = sns.load_dataset("iris")
#     sns.pairplot(iris, hue='species', palette='RdYlBu', height=8, kind='reg', diag_kind='kde')

    
def classify(x, c, R=0.01):
        if x<=-R:
            c[0]+=1
            return 0
        elif -R<x<R:
            c[1]+=1
            return 1
        elif R<=x:
            c[2]+=1
            return 2
        
def classify_two(x, c):
        if x<=0:
            c[0]+=1
            return 0
        elif 0<x:
            c[2]+=1
            return 2

def predict(dataname):

    df = pd.read_csv(dataname, index_col='Datetime')
    count = [0,0,0]
    #df['class'] = (df["Rate"]).apply(lambda x: classify(x, count, 0.001))
    df['class'] = (df["Rate"]).apply(lambda x: classify_two(x, count))
    df['class'] = df['class'].shift(-1)
    print(" LOW/MID/HIGH")
    print(count)
    
    
    X = df.drop('class', axis=1)
    y = df['class']
    X = X.drop(X.index[len(X)-1])
    y = y.dropna()
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)
    
    names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
             "Random Forest", "AdaBoost", "Naive Bayes", "Linear Discriminant Analysis",
             "Quadratic Discriminant Analysis"]
    classifiers = [
        KNeighborsClassifier(3),
        SVC(kernel="linear", C=0.025),
        SVC(gamma=2, C=1),
        DecisionTreeClassifier(max_depth=5),
        RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
        AdaBoostClassifier(),
        GaussianNB(),
        LinearDiscriminantAnalysis(),
        QuadraticDiscriminantAnalysis()]
    
    accuracy_scores = []
    precision_scores = []
    
    
    for name, clf in zip(names, classifiers):
        print(name)
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        result = clf.predict(X_test)
        
        print('accuracy_score: ', end='')
        print(accuracy_score(y_test, result))
        accuracy_scores.extend([accuracy_score(y_test, result)])
        print('confusion_matrix: ')
        print(confusion_matrix(y_test, result))
        print('precision_score: ', end='')
        print(precision_score(y_test, result, average=None))
        precision_scores.extend([precision_score(y_test, result, average=None)])
        
        possestion = 50000
        pay = 5000
        po_rate = 1.95
        
        for i in range(len(result)):
            possestion -= pay
            if (result[i]==0):#Low予想のとき
                if (result[i]==y_test[i]): #予測成功
                    possestion += pay*po_rate

            elif(result[i]==2):#High予想の時
                if (result[i]==y_test[i]): #予測成功
                    possestion += pay*po_rate
            else:  #Mid予想の時
                possestion += pay
        print(str(len(result))+"days trade")
        print("posestion: "+ str(possestion))
        
        print('')
    
    print(accuracy_scores)
    print(precision_scores)

def main():
    namelist = ['20101to20208_USD_JPY_D.csv','20101to20208_EUR_JPY_D.csv','20101to20208_AUD_JPY_D.csv','20101to20208_GBP_JPY_D.csv','20101to20208_NZD_JPY_D.csv','20101to20208_CAD_JPY_D.csv','20101to20208_CHF_JPY_D.csv','20101to20208_ZAR_JPY_D.csv']
    
    for i in range(len(namelist)):
        print(namelist[i])
        predict(namelist[i]) 
        #show_data_relation(namelist[i])
    

main()
# Out:
# 20101to20208_USD_JPY_D.csv
#  LOW/MID/HIGH
# [1158, 0, 1031]
# Nearest Neighbors
# accuracy_score: 0.4840182648401826
# confusion_matrix:
# [[109 117]
#  [109 103]]
# precision_score: [0.5        0.46818182]
# 438days trade
# posestion: -73000.0
#
# Linear SVM
# accuracy_score: 0.5045662100456622
# confusion_matrix:
# [[215  11]
#  [206   6]]
# precision_score: [0.51068884 0.35294118]
# 438days trade
# posestion: 14750.0
#
# RBF SVM
# accuracy_score: 0.4977168949771689
# confusion_matrix:
# [[214  12]
#  [208   4]]
# precision_score: [0.507109 0.25    ]
# 438days trade
# posestion: -14500.0
#
# Decision Tree
# accuracy_score: 0.5182648401826484
# confusion_matrix:
# [[220   6]
#  [205   7]]
# precision_score: [0.51764706 0.53846154]
# 438days trade
# posestion: 73250.0
#
# Random Forest
# accuracy_score: 0.5114155251141552
# confusion_matrix:
# [[153  73]
#  [141  71]]
# precision_score: [0.52040816 0.49305556]
# 438days trade
# posestion: 44000.0
#
# AdaBoost
# accuracy_score: 0.5365296803652968
# confusion_matrix:
# [[163  63]
#  [140  72]]
# precision_score: [0.5379538  0.53333333]
# 438days trade
# posestion: 151250.0
#
# Naive Bayes
# accuracy_score: 0.5068493150684932
# confusion_matrix:
# [[152  74]
#  [142  70]]
# precision_score: [0.5170068  0.48611111]
# 438days trade
# posestion: 24500.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.5114155251141552
# confusion_matrix:
# [[206  20]
#  [194  18]]
# precision_score: [0.515      0.47368421]
# 438days trade
# posestion: 44000.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.5228310502283106
# confusion_matrix:
# [[192  34]
#  [175  37]]
# precision_score: [0.52316076 0.52112676]
# 438days trade
# posestion: 92750.0
#
# [0.4840182648401826, 0.5045662100456622, 0.4977168949771689, 0.5182648401826484, 0.5114155251141552, 0.5365296803652968, 0.5068493150684932, 0.5114155251141552, 0.5228310502283106]
# [array([0.5       , 0.46818182]), array([0.51068884, 0.35294118]), array([0.507109, 0.25    ]), array([0.51764706, 0.53846154]), array([0.52040816, 0.49305556]), array([0.5379538 , 0.53333333]), array([0.5170068 , 0.48611111]), array([0.515     , 0.47368421]), array([0.52316076, 0.52112676])]
# 20101to20208_EUR_JPY_D.csv
#  LOW/MID/HIGH
# [1128, 0, 1053]
# Nearest Neighbors
# accuracy_score: 0.5321100917431193
# confusion_matrix:
# [[130 106]
#  [ 98 102]]
# precision_score: [0.57017544 0.49038462]
# 436days trade
# posestion: 132000.0
#
# Linear SVM
# accuracy_score: 0.5412844036697247
# confusion_matrix:
# [[236   0]
#  [200   0]]
# precision_score: [0.5412844 0.       ]
# 436days trade
# posestion: 171000.0
#
# RBF SVM
# C:\Users\stana\.conda\envs\predict_rate\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# accuracy_score: 0.5389908256880734
# confusion_matrix:
# [[226  10]
#  [191   9]]
# precision_score: [0.54196643 0.47368421]
# 436days trade
# posestion: 161250.0
#
# Decision Tree
# accuracy_score: 0.518348623853211
# confusion_matrix:
# [[152  84]
#  [126  74]]
# precision_score: [0.54676259 0.46835443]
# 436days trade
# posestion: 73500.0
#
# Random Forest
# accuracy_score: 0.5160550458715596
# confusion_matrix:
# [[158  78]
#  [133  67]]
# precision_score: [0.54295533 0.46206897]
# 436days trade
# posestion: 63750.0
#
# AdaBoost
# accuracy_score: 0.5137614678899083
# confusion_matrix:
# [[135 101]
#  [111  89]]
# precision_score: [0.54878049 0.46842105]
# 436days trade
# posestion: 54000.0
#
# Naive Bayes
# accuracy_score: 0.5114678899082569
# confusion_matrix:
# [[148  88]
#  [125  75]]
# precision_score: [0.54212454 0.4601227 ]
# 436days trade
# posestion: 44250.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.5045871559633027
# confusion_matrix:
# [[176  60]
#  [156  44]]
# precision_score: [0.53012048 0.42307692]
# 436days trade
# posestion: 15000.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.5206422018348624
# confusion_matrix:
# [[203  33]
#  [176  24]]
# precision_score: [0.53562005 0.42105263]
# 436days trade
# posestion: 83250.0
#
# [0.5321100917431193, 0.5412844036697247, 0.5389908256880734, 0.518348623853211, 0.5160550458715596, 0.5137614678899083, 0.5114678899082569, 0.5045871559633027, 0.5206422018348624]
# [array([0.57017544, 0.49038462]), array([0.5412844, 0.       ]), array([0.54196643, 0.47368421]), array([0.54676259, 0.46835443]), array([0.54295533, 0.46206897]), array([0.54878049, 0.46842105]), array([0.54212454, 0.4601227 ]), array([0.53012048, 0.42307692]), array([0.53562005, 0.42105263])]
# 20101to20208_AUD_JPY_D.csv
#  LOW/MID/HIGH
# [1087, 0, 1092]
# Nearest Neighbors
# accuracy_score: 0.46788990825688076
# confusion_matrix:
# [[103 115]
#  [117 101]]
# precision_score: [0.46818182 0.46759259]
# 436days trade
# posestion: -141000.0
#
# Linear SVM
# accuracy_score: 0.5022935779816514
# confusion_matrix:
# [[ 13 205]
#  [ 12 206]]
# precision_score: [0.52       0.50121655]
# 436days trade
# posestion: 5250.0
#
# RBF SVM
# accuracy_score: 0.5
# confusion_matrix:
# [[  6 212]
#  [  6 212]]
# precision_score: [0.5 0.5]
# 436days trade
# posestion: -4500.0
#
# Decision Tree
# accuracy_score: 0.4908256880733945
# confusion_matrix:
# [[ 16 202]
#  [ 20 198]]
# precision_score: [0.44444444 0.495     ]
# 436days trade
# posestion: -43500.0
#
# Random Forest
# accuracy_score: 0.47706422018348627
# confusion_matrix:
# [[123  95]
#  [133  85]]
# precision_score: [0.48046875 0.47222222]
# 436days trade
# posestion: -102000.0
#
# AdaBoost
# accuracy_score: 0.49770642201834864
# confusion_matrix:
# [[122  96]
#  [123  95]]
# precision_score: [0.49795918 0.4973822 ]
# 436days trade
# posestion: -14250.0
#
# Naive Bayes
# accuracy_score: 0.5527522935779816
# confusion_matrix:
# [[171  47]
#  [148  70]]
# precision_score: [0.53605016 0.5982906 ]
# 436days trade
# posestion: 219750.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.536697247706422
# confusion_matrix:
# [[119  99]
#  [103 115]]
# precision_score: [0.53603604 0.53738318]
# 436days trade
# posestion: 151500.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.5160550458715596
# confusion_matrix:
# [[185  33]
#  [178  40]]
# precision_score: [0.50964187 0.54794521]
# 436days trade
# posestion: 63750.0
#
# [0.46788990825688076, 0.5022935779816514, 0.5, 0.4908256880733945, 0.47706422018348627, 0.49770642201834864, 0.5527522935779816, 0.536697247706422, 0.5160550458715596]
# [array([0.46818182, 0.46759259]), array([0.52      , 0.50121655]), array([0.5, 0.5]), array([0.44444444, 0.495     ]), array([0.48046875, 0.47222222]), array([0.49795918, 0.4973822 ]), array([0.53605016, 0.5982906 ]), array([0.53603604, 0.53738318]), array([0.50964187, 0.54794521])]
# 20101to20208_GBP_JPY_D.csv
#  LOW/MID/HIGH
# [1106, 0, 1075]
# Nearest Neighbors
# accuracy_score: 0.5045871559633027
# confusion_matrix:
# [[107 108]
#  [108 113]]
# precision_score: [0.49767442 0.51131222]
# 436days trade
# posestion: 15000.0
#
# Linear SVM
# accuracy_score: 0.45642201834862384
# confusion_matrix:
# [[187  28]
#  [209  12]]
# precision_score: [0.47222222 0.3       ]
# 436days trade
# posestion: -189750.0
#
# RBF SVM
# accuracy_score: 0.5022935779816514
# confusion_matrix:
# [[209   6]
#  [211  10]]
# precision_score: [0.49761905 0.625     ]
# 436days trade
# posestion: 5250.0
#
# Decision Tree
# accuracy_score: 0.5458715596330275
# confusion_matrix:
# [[176  39]
#  [159  62]]
# precision_score: [0.52537313 0.61386139]
# 436days trade
# posestion: 190500.0
#
# Random Forest
# accuracy_score: 0.5045871559633027
# confusion_matrix:
# [[131  84]
#  [132  89]]
# precision_score: [0.49809886 0.51445087]
# 436days trade
# posestion: 15000.0
#
# AdaBoost
# accuracy_score: 0.5527522935779816
# confusion_matrix:
# [[142  73]
#  [122  99]]
# precision_score: [0.53787879 0.5755814 ]
# 436days trade
# posestion: 219750.0
#
# Naive Bayes
# accuracy_score: 0.5045871559633027
# confusion_matrix:
# [[185  30]
#  [186  35]]
# precision_score: [0.49865229 0.53846154]
# 436days trade
# posestion: 15000.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.5619266055045872
# confusion_matrix:
# [[167  48]
#  [143  78]]
# precision_score: [0.53870968 0.61904762]
# 436days trade
# posestion: 258750.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.5642201834862385
# confusion_matrix:
# [[ 78 137]
#  [ 53 168]]
# precision_score: [0.59541985 0.55081967]
# 436days trade
# posestion: 268500.0
#
# [0.5045871559633027, 0.45642201834862384, 0.5022935779816514, 0.5458715596330275, 0.5045871559633027, 0.5527522935779816, 0.5045871559633027, 0.5619266055045872, 0.5642201834862385]
# [array([0.49767442, 0.51131222]), array([0.47222222, 0.3       ]), array([0.49761905, 0.625     ]), array([0.52537313, 0.61386139]), array([0.49809886, 0.51445087]), array([0.53787879, 0.5755814 ]), array([0.49865229, 0.53846154]), array([0.53870968, 0.61904762]), array([0.59541985, 0.55081967])]
# 20101to20208_NZD_JPY_D.csv
#  LOW/MID/HIGH
# [1101, 0, 1088]
# Nearest Neighbors
# accuracy_score: 0.4977168949771689
# confusion_matrix:
# [[105 108]
#  [112 113]]
# precision_score: [0.48387097 0.51131222]
# 438days trade
# posestion: -14500.0
#
# Linear SVM
# accuracy_score: 0.4977168949771689
# confusion_matrix:
# [[196  17]
#  [203  22]]
# precision_score: [0.49122807 0.56410256]
# 438days trade
# posestion: -14500.0
#
# RBF SVM
# accuracy_score: 0.4931506849315068
# confusion_matrix:
# [[208   5]
#  [217   8]]
# precision_score: [0.48941176 0.61538462]
# 438days trade
# posestion: -34000.0
#
# Decision Tree
# accuracy_score: 0.5296803652968036
# confusion_matrix:
# [[102 111]
#  [ 95 130]]
# precision_score: [0.5177665  0.53941909]
# 438days trade
# posestion: 122000.0
#
# Random Forest
# accuracy_score: 0.5365296803652968
# confusion_matrix:
# [[165  48]
#  [155  70]]
# precision_score: [0.515625   0.59322034]
# 438days trade
# posestion: 151250.0
#
# AdaBoost
# accuracy_score: 0.5388127853881278
# confusion_matrix:
# [[134  79]
#  [123 102]]
# precision_score: [0.52140078 0.56353591]
# 438days trade
# posestion: 161000.0
#
# Naive Bayes
# accuracy_score: 0.5
# confusion_matrix:
# [[140  73]
#  [146  79]]
# precision_score: [0.48951049 0.51973684]
# 438days trade
# posestion: -4750.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.502283105022831
# confusion_matrix:
# [[124  89]
#  [129  96]]
# precision_score: [0.49011858 0.51891892]
# 438days trade
# posestion: 5000.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.547945205479452
# confusion_matrix:
# [[148  65]
#  [133  92]]
# precision_score: [0.52669039 0.58598726]
# 438days trade
# posestion: 200000.0
#
# [0.4977168949771689, 0.4977168949771689, 0.4931506849315068, 0.5296803652968036, 0.5365296803652968, 0.5388127853881278, 0.5, 0.502283105022831, 0.547945205479452]
# [array([0.48387097, 0.51131222]), array([0.49122807, 0.56410256]), array([0.48941176, 0.61538462]), array([0.5177665 , 0.53941909]), array([0.515625  , 0.59322034]), array([0.52140078, 0.56353591]), array([0.48951049, 0.51973684]), array([0.49011858, 0.51891892]), array([0.52669039, 0.58598726])]
# 20101to20208_CAD_JPY_D.csv
#  LOW/MID/HIGH
# [1125, 0, 1055]
# Nearest Neighbors
# accuracy_score: 0.5022935779816514
# confusion_matrix:
# [[118 119]
#  [ 98 101]]
# precision_score: [0.5462963  0.45909091]
# 436days trade
# posestion: 5250.0
#
# Linear SVM
# accuracy_score: 0.5321100917431193
# confusion_matrix:
# [[216  21]
#  [183  16]]
# precision_score: [0.54135338 0.43243243]
# 436days trade
# posestion: 132000.0
#
# RBF SVM
# accuracy_score: 0.5206422018348624
# confusion_matrix:
# [[224  13]
#  [196   3]]
# precision_score: [0.53333333 0.1875    ]
# 436days trade
# posestion: 83250.0
#
# Decision Tree
# accuracy_score: 0.48623853211009177
# confusion_matrix:
# [[ 89 148]
#  [ 76 123]]
# precision_score: [0.53939394 0.45387454]
# 436days trade
# posestion: -63000.0
#
# Random Forest
# accuracy_score: 0.5022935779816514
# confusion_matrix:
# [[128 109]
#  [108  91]]
# precision_score: [0.54237288 0.455     ]
# 436days trade
# posestion: 5250.0
#
# AdaBoost
# accuracy_score: 0.48394495412844035
# confusion_matrix:
# [[141  96]
#  [129  70]]
# precision_score: [0.52222222 0.42168675]
# 436days trade
# posestion: -72750.0
#
# Naive Bayes
# accuracy_score: 0.5252293577981652
# confusion_matrix:
# [[183  54]
#  [153  46]]
# precision_score: [0.54464286 0.46      ]
# 436days trade
# posestion: 102750.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.5389908256880734
# confusion_matrix:
# [[195  42]
#  [159  40]]
# precision_score: [0.55084746 0.48780488]
# 436days trade
# posestion: 161250.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.5481651376146789
# confusion_matrix:
# [[203  34]
#  [163  36]]
# precision_score: [0.55464481 0.51428571]
# 436days trade
# posestion: 200250.0
#
# [0.5022935779816514, 0.5321100917431193, 0.5206422018348624, 0.48623853211009177, 0.5022935779816514, 0.48394495412844035, 0.5252293577981652, 0.5389908256880734, 0.5481651376146789]
# [array([0.5462963 , 0.45909091]), array([0.54135338, 0.43243243]), array([0.53333333, 0.1875    ]), array([0.53939394, 0.45387454]), array([0.54237288, 0.455     ]), array([0.52222222, 0.42168675]), array([0.54464286, 0.46      ]), array([0.55084746, 0.48780488]), array([0.55464481, 0.51428571])]
# 20101to20208_CHF_JPY_D.csv
#  LOW/MID/HIGH
# [1099, 0, 1082]
# Nearest Neighbors
# accuracy_score: 0.47477064220183485
# confusion_matrix:
# [[ 97 128]
#  [101 110]]
# precision_score: [0.48989899 0.46218487]
# 436days trade
# posestion: -111750.0
#
# Linear SVM
# accuracy_score: 0.4954128440366973
# confusion_matrix:
# [[175  50]
#  [170  41]]
# precision_score: [0.50724638 0.45054945]
# 436days trade
# posestion: -24000.0
#
# RBF SVM
# accuracy_score: 0.5206422018348624
# confusion_matrix:
# [[216   9]
#  [200  11]]
# precision_score: [0.51923077 0.55      ]
# 436days trade
# posestion: 83250.0
#
# Decision Tree
# accuracy_score: 0.5
# confusion_matrix:
# [[121 104]
#  [114  97]]
# precision_score: [0.51489362 0.48258706]
# 436days trade
# posestion: -4500.0
#
# Random Forest
# accuracy_score: 0.5160550458715596
# confusion_matrix:
# [[121 104]
#  [107 104]]
# precision_score: [0.53070175 0.5       ]
# 436days trade
# posestion: 63750.0
#
# AdaBoost
# accuracy_score: 0.5275229357798165
# confusion_matrix:
# [[113 112]
#  [ 94 117]]
# precision_score: [0.54589372 0.51091703]
# 436days trade
# posestion: 112500.0
#
# Naive Bayes
# accuracy_score: 0.5114678899082569
# confusion_matrix:
# [[164  61]
#  [152  59]]
# precision_score: [0.51898734 0.49166667]
# 436days trade
# posestion: 44250.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.5252293577981652
# confusion_matrix:
# [[137  88]
#  [119  92]]
# precision_score: [0.53515625 0.51111111]
# 436days trade
# posestion: 102750.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.4793577981651376
# confusion_matrix:
# [[ 14 211]
#  [ 16 195]]
# precision_score: [0.46666667 0.48029557]
# 436days trade
# posestion: -92250.0
#
# [0.47477064220183485, 0.4954128440366973, 0.5206422018348624, 0.5, 0.5160550458715596, 0.5275229357798165, 0.5114678899082569, 0.5252293577981652, 0.4793577981651376]
# [array([0.48989899, 0.46218487]), array([0.50724638, 0.45054945]), array([0.51923077, 0.55      ]), array([0.51489362, 0.48258706]), array([0.53070175, 0.5       ]), array([0.54589372, 0.51091703]), array([0.51898734, 0.49166667]), array([0.53515625, 0.51111111]), array([0.46666667, 0.48029557])]
# 20101to20208_ZAR_JPY_D.csv
#  LOW/MID/HIGH
# [1133, 0, 1042]
# Nearest Neighbors
# accuracy_score: 0.5241379310344828
# confusion_matrix:
# [[125 102]
#  [105 103]]
# precision_score: [0.54347826 0.50243902]
# 435days trade
# posestion: 98000.0
#
# Linear SVM
# accuracy_score: 0.5103448275862069
# confusion_matrix:
# [[180  47]
#  [166  42]]
# precision_score: [0.52023121 0.47191011]
# 435days trade
# posestion: 39500.0
#
# RBF SVM
# accuracy_score: 0.5241379310344828
# confusion_matrix:
# [[212  15]
#  [192  16]]
# precision_score: [0.52475248 0.51612903]
# 435days trade
# posestion: 98000.0
#
# Decision Tree
# accuracy_score: 0.5011494252873563
# confusion_matrix:
# [[139  88]
#  [129  79]]
# precision_score: [0.51865672 0.47305389]
# 435days trade
# posestion: 500.0
#
# Random Forest
# accuracy_score: 0.5080459770114942
# confusion_matrix:
# [[157  70]
#  [144  64]]
# precision_score: [0.52159468 0.47761194]
# 435days trade
# posestion: 29750.0
#
# AdaBoost
# accuracy_score: 0.5195402298850574
# confusion_matrix:
# [[166  61]
#  [148  60]]
# precision_score: [0.52866242 0.49586777]
# 435days trade
# posestion: 78500.0
#
# Naive Bayes
# accuracy_score: 0.5149425287356322
# confusion_matrix:
# [[139  88]
#  [123  85]]
# precision_score: [0.53053435 0.49132948]
# 435days trade
# posestion: 59000.0
#
# Linear Discriminant Analysis
# accuracy_score: 0.496551724137931
# confusion_matrix:
# [[166  61]
#  [158  50]]
# precision_score: [0.51234568 0.45045045]
# 435days trade
# posestion: -19000.0
#
# Quadratic Discriminant Analysis
# accuracy_score: 0.4827586206896552
# confusion_matrix:
# [[ 95 132]
#  [ 93 115]]
# precision_score: [0.50531915 0.46558704]
# 435days trade
# posestion: -77500.0
#
# [0.5241379310344828, 0.5103448275862069, 0.5241379310344828, 0.5011494252873563, 0.5080459770114942, 0.5195402298850574, 0.5149425287356322, 0.496551724137931, 0.4827586206896552]
# [array([0.54347826, 0.50243902]), array([0.52023121, 0.47191011]), array([0.52475248, 0.51612903]), array([0.51865672, 0.47305389]), array([0.52159468, 0.47761194]), array([0.52866242, 0.49586777]), array([0.53053435, 0.49132948]), array([0.51234568, 0.45045045]), array([0.50531915, 0.46558704])]

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score

from testing_for_data import get_now_data

def show_data_relation(dataname):
    df = pd.read_csv(dataname, index_col='Datetime')
    df = df.astype('double')
    
    count = [0, 0, 0]
    df['class'] = (df["Rate"]).apply(lambda x: classify(x, count, 0.001))
    df['class'] = df['class'].shift(-1)
    print(' LOW/MID/HIGH')
    print(count)
    sns.pairplot(df, hue='class', palette='RdYlBu', height=8, kind='reg').savefig('./data_plot'+dataname+'.png')
    
#     iris = sns.load_dataset("iris")
#     sns.pairplot(iris, hue='species', palette='RdYlBu', height=8, kind='reg', diag_kind='kde')

    
def classify(x, c, R=0.001):
        if x<=-R:
            c[0]+=1
            return 0
        elif -R<x<R:
            c[1]+=1
            return 1
        elif R<=x:
            c[2]+=1
            return 2
        
def classify_two(x, c):
        if x<=0:
            c[0]+=1
            return 0
        elif 0<x:
            c[2]+=1
            return 2

def predict(dataname, moneyname, days):

    df = pd.read_csv(dataname, index_col='Datetime')
    count = [0,0,0]
    #df['class'] = (df["Rate"]).apply(lambda x: classify(x, count, 0.001))
    df['class'] = (df["Rate"]).apply(lambda x: classify(x, count))
    df['class'] = df['class'].shift(-1)
    print("Train Data")
    print(" LOW/MID/HIGH")
    print(count)
    
    X = df.drop('class', axis=1)
    y = df['class']
    X = X.drop(X.index[len(X)-1])
    y = y.dropna()
    
    #X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, shuffle=False)
    #df_now = pd.read_csv('now_data.csv', index_col='Datetime')
    df_now = get_now_data(period_Days=days, money=moneyname, foot = 'D', back_days = 1)
    print("money: "+moneyname)
    count = [0,0,0]
    #df['class'] = (df["Rate"]).apply(lambda x: classify(x, count, 0.001))
    df_now['class'] = (df_now["Rate"]).apply(lambda x: classify(x, count))
    df_now['class'] = df_now['class'].shift(-1)
    print("NOW Data from" +str(days)+ "days ago")
    print(" LOW/MID/HIGH")
    print(count)
    
    print(df_now.head(1))
    print(df_now.tail(1))
    X_now = df_now.drop('class', axis=1)
    
    
    X_next = X_now.tail(1) #最終予測に利用
    y_now = df_now['class']
    X_now = X_now.drop(X_now.index[len(X_now)-1])
    y_now = y_now.dropna()
    
    X_train = X
    y_train = y
    X_test = X_now
    y_test = y_now
    
    
    
    
    names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
             "Random Forest", "AdaBoost", "Naive Bayes", "Linear Discriminant Analysis",
             "Quadratic Discriminant Analysis"]
    classifiers = [
        KNeighborsClassifier(3),
        SVC(kernel="linear", C=0.025),
        SVC(gamma=2, C=1),
        DecisionTreeClassifier(max_depth=10),
        RandomForestClassifier(max_depth=10, n_estimators=10, max_features=1),
        AdaBoostClassifier(),
        GaussianNB(),
        LinearDiscriminantAnalysis(),
        QuadraticDiscriminantAnalysis()]
    
    accuracy_scores = []
    precision_scores = []
    next_class = []
    profit = []
    
    
    for name, clf in zip(names, classifiers):
        print(name)
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        result = clf.predict(X_test)
        next_class.extend(clf.predict(X_next))
        
        print('accuracy_score: ', end='')
        print(accuracy_score(y_test, result))
        accuracy_scores.extend([accuracy_score(y_test, result)])
        print('confusion_matrix: ')
        print(confusion_matrix(y_test, result))
        print('precision_score: ', end='')
        print(precision_score(y_test, result, average=None))
        precision_scores.extend([precision_score(y_test, result, average=None)])
        
        possestion = 50000
        pay = possestion*0.1
        po_rate = 1.95
        
        win = 0
        lose = 0
        
        for i in range(len(result)):
            possestion -= pay
            if (result[i]==0):#Low予想のとき
                if (result[i]==y_test[i]): #予測成功
                    possestion += pay*po_rate
                    win+=1
                else:
                    lose+=1

            elif(result[i]==2):#High予想の時
                if (result[i]==y_test[i]): #予測成功
                    possestion += pay*po_rate
                    win+=1
                else:
                    lose+=1
            else:  #Mid予想の時
                possestion += pay
        print(str(len(result))+"days trade")
        print("posestion: "+ str(possestion))
        print("profit: "+str(win*0.95-lose))
        
        print('')
        
        profit.extend([win*0.95-lose])
    
    return accuracy_scores, precision_scores, next_class, profit

def main(times=0):
    namelist = ['20101to20208_USD_JPY_D.csv','20101to20208_EUR_JPY_D.csv','20101to20208_AUD_JPY_D.csv','20101to20208_GBP_JPY_D.csv','20101to20208_NZD_JPY_D.csv','20101to20208_CAD_JPY_D.csv','20101to20208_CHF_JPY_D.csv','20101to20208_ZAR_JPY_D.csv']
    moneylist = ['USD_JPY', 'EUR_JPY', 'AUD_JPY', 'GBP_JPY', 'NZD_JPY', 'CAD_JPY', 'CHF_JPY', 'ZAR_JPY', 'Average']
    
    df = pd.DataFrame(index=['USD_JPY', 'EUR_JPY', 'AUD_JPY', 'GBP_JPY', 'NZD_JPY', 'CAD_JPY', 'CHF_JPY', 'ZAR_JPY', 'Average'], columns = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
             "Random Forest", "AdaBoost", "Naive Bayes", "Linear Discriminant Analysis",
             "Quadratic Discriminant Analysis"])
    
    df_pre = pd.DataFrame(index=['USD_JPY', 'EUR_JPY', 'AUD_JPY', 'GBP_JPY', 'NZD_JPY', 'CAD_JPY', 'CHF_JPY', 'ZAR_JPY', 'Average'], columns = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
             "Random Forest", "AdaBoost", "Naive Bayes", "Linear Discriminant Analysis",
             "Quadratic Discriminant Analysis"])
    
    df_next = pd.DataFrame(index=['USD_JPY', 'EUR_JPY', 'AUD_JPY', 'GBP_JPY', 'NZD_JPY', 'CAD_JPY', 'CHF_JPY', 'ZAR_JPY'], columns = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
             "Random Forest", "AdaBoost", "Naive Bayes", "Linear Discriminant Analysis",
             "Quadratic Discriminant Analysis"])
    
    df_profit = pd.DataFrame(index=['USD_JPY', 'EUR_JPY', 'AUD_JPY', 'GBP_JPY', 'NZD_JPY', 'CAD_JPY', 'CHF_JPY', 'ZAR_JPY', 'Average'], columns = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Decision Tree",
             "Random Forest", "AdaBoost", "Naive Bayes", "Linear Discriminant Analysis",
             "Quadratic Discriminant Analysis"])
    
    for i in range(len(namelist)):
        print(namelist[i])
        acc, pre, next_class, profit = predict(namelist[i], moneylist[i], days = 60)
        print(acc)
        df.loc[moneylist[i]]=acc
        df_pre.loc[moneylist[i]]=pre
        df_next.loc[moneylist[i]]=next_class
        df_profit.loc[moneylist[i]]=profit
        
    
    df.loc[moneylist[i+1]] = df.mean()
    df_pre.loc[moneylist[i+1]] = df_pre.mean()
    df_profit.loc[moneylist[i+1]] = df_profit.mean()
    print(df)
    print(df_pre)
    print(df_next)
    print(df_profit)
    df.to_csv('accuracy_result_'+str(times)+'.csv', mode = 'w')
    df_pre.to_csv('precision_result_'+str(times)+'.csv', mode = 'w')
    df_next.to_csv('predict_result_'+str(times)+'.csv', mode = 'w')
    df_profit.to_csv('profit_result_'+str(times)+'.csv', mode = 'w')
    
    
main()
# Out:
# 20101to20208_USD_JPY_D.csv
# Train Data
#  LOW/MID/HIGH
# [815, 573, 801]
# money: USD_JPY
# NOW Data from60days ago
#  LOW/MID/HIGH
# [16, 15, 13]
#                   Volume    Open     High      Low    Close      Rate  class
# Datetime
# 2020-09-06 21:00   41251  106.26  106.386  106.133  106.272  0.000113    0.0
#                   Volume     Open     High      Low    Close      Rate  class
# Datetime
# 2020-11-04 22:00  110775  104.516  104.549  103.442  103.504 -0.009683    NaN
# Nearest Neighbors
# accuracy_score: 0.27906976744186046
# confusion_matrix:
# [[8 1 7]
#  [9 0 5]
#  [8 1 4]]
# precision_score: [0.32 0.   0.25]
# 43days trade
# posestion: -38000.0
# profit: -17.6
#
# Linear SVM
